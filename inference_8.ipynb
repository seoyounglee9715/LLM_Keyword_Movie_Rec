# %%
# model8 inference
# train data: 8000개, eval data: 2000개

# %%
import torch
from transformers import (
    AutoModelForCausalLM,
    LlamaTokenizerFast,
    TrainingArguments,
    Trainer,
    BitsAndBytesConfig,
)
from peft import (
    LoraConfig,
    get_peft_model,
    PeftModel
)
# Out:
# 2024-04-19 20:59:55.700295: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-19 20:59:55.809178: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-19 20:59:56.297999: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2024-04-19 20:59:56.298055: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2024-04-19 20:59:56.298059: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
base_model = "meta-llama/Llama-2-7b-chat-hf"

# %%
# QLoRA 모델을 사용하기 위한 설정

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16 
)

# %%
# 라마2 모델 불러오기
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    quantization_config=bnb_config,
    device_map="auto",
)
model.config.use_cache = False
model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# 토크나이저 로드
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false" # 토크나이저 병렬처리 방지(오류 방지)
os.environ['TRANSFORMERS_NO_ADVISORY_WARNINGS'] = 'true' # __cell__ 오류 방지

tokenizer = LlamaTokenizerFast.from_pretrained(
    base_model,
    trust_remote_code=True
)
tokenizer.pad_token = tokenizer.eos_token # 패딩 토큰을 문장의 끝으로 설정 </s>
tokenizer.padding_side = "right" # 패딩을 문장 뒤에 추가

# %%
# 어댑터 추가
model = PeftModel.from_pretrained(model, "/data/ngn_2024/llm_auto_train/models8/ckpt")

# %%
# 학습 양식
import json
from datasets import load_dataset
file_name = 'preprocess/dataset3/new_ratings_4.json'

# %%
import json

# JSON 파일 불러오기
input_file = file_name
with open(input_file, 'r') as f:
    data = json.load(f)

# %%
# 데이터셋 로드
data = load_dataset('json', data_files=file_name, split="train")

# %%
instruction = '''
I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
'''

# %%
# 데이터 매핑 함수 정의
def map_data_to_format(example):

    user_ratings_str = json.dumps(example['ratings'], ensure_ascii=False)
    rank_list_str = json.dumps(example["rank"], ensure_ascii=False)
    
    text = (
        f"###instruction:\n{instruction}\n\n"
        f"user_rating_information:\n{user_ratings_str}\n\n"
        f"###response:\n{rank_list_str}\n\n"
    )
    
    # completion은 모델이 생성해야 할 예상 출력을 포함함
    # 여기서는 우선순위에 따라 정렬된 영화 imdb_id의 리스트를 반환합니다.
    completion = f"{{\"rank\": {rank_list_str}}}"
    
    return {'text': text, 'completion': completion}

# %%
# 데이터 매핑 적용
mapped_data = data.map(map_data_to_format)
print(mapped_data)
# Out:
# Dataset({
#     features: ['rank', 'ratings', 'userId', 'text', 'completion'],
#     num_rows: 10000
# })

# %%
# 데이터셋 분할
split_data = mapped_data.train_test_split(test_size=0.1)  # 10%를 테스트셋으로 사용

train_set = split_data['train']
eval_set = split_data['test']

train_set = train_set.map(lambda samples: tokenizer(samples["text"], padding=True, truncation=True, return_tensors="pt"), batched=True)
eval_set = eval_set.map(lambda samples: tokenizer(samples["text"], padding=True, truncation=True, return_tensors="pt"), batched=True)
# Out:
# Map:   0%|          | 0/9000 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
print(eval_set[90]["text"])
# Out:
# ###instruction:
#
# I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
# user_rating_information:
# [{"imdbId": "tt401792", "rating": 4.5, "timestamp": 1368896424, "title": "Sin City (2005)"}, {"imdbId": "tt375679", "rating": 4.5, "timestamp": 1368893832, "title": "Crash (2004)"}, {"imdbId": "tt374536", "rating": 2.5, "timestamp": 1368897031, "title": "Bewitched (2005)"}, {"imdbId": "tt405422", "rating": 3.0, "timestamp": 1368896664, "title": "40-Year-Old Virgin, The (2005)"}, {"imdbId": "tt399295", "rating": 3.5, "timestamp": 1368894060, "title": "Lord of War (2005)"}, {"imdbId": "tt424136", "rating": 5.0, "timestamp": 1368896464, "title": "Hard Candy (2005)"}, {"imdbId": "tt457430", "rating": 4.0, "timestamp": 1368896435, "title": "Pan's Labyrinth (Laberinto del fauno, El) (2006)"}, {"imdbId": "tt457939", "rating": 3.5, "timestamp": 1368896701, "title": "Holiday, The (2006)"}, {"imdbId": "tt457572", "rating": 4.0, "timestamp": 1368893067, "title": "Fido (2006)"}, {"imdbId": "tt1028528", "rating": 3.0, "timestamp": 1368893084, "title": "Death Proof (2007)"}]
#
# ###response:
# [{"title": "Hard Candy (2005)"}, {"title": "Sin City (2005)"}, {"title": "Crash (2004)"}, {"title": "Pan's Labyrinth (Laberinto del fauno, El) (2006)"}, {"title": "Fido (2006)"}, {"title": "Holiday, The (2006)"}, {"title": "Lord of War (2005)"}, {"title": "40-Year-Old Virgin, The (2005)"}, {"title": "Death Proof (2007)"}, {"title": "Bewitched (2005)"}]

# %%
print(eval_set[90]["ratings"])
# Out:
# [{'imdbId': 'tt401792', 'rating': 4.5, 'timestamp': 1368896424, 'title': 'Sin City (2005)'}, {'imdbId': 'tt375679', 'rating': 4.5, 'timestamp': 1368893832, 'title': 'Crash (2004)'}, {'imdbId': 'tt374536', 'rating': 2.5, 'timestamp': 1368897031, 'title': 'Bewitched (2005)'}, {'imdbId': 'tt405422', 'rating': 3.0, 'timestamp': 1368896664, 'title': '40-Year-Old Virgin, The (2005)'}, {'imdbId': 'tt399295', 'rating': 3.5, 'timestamp': 1368894060, 'title': 'Lord of War (2005)'}, {'imdbId': 'tt424136', 'rating': 5.0, 'timestamp': 1368896464, 'title': 'Hard Candy (2005)'}, {'imdbId': 'tt457430', 'rating': 4.0, 'timestamp': 1368896435, 'title': "Pan's Labyrinth (Laberinto del fauno, El) (2006)"}, {'imdbId': 'tt457939', 'rating': 3.5, 'timestamp': 1368896701, 'title': 'Holiday, The (2006)'}, {'imdbId': 'tt457572', 'rating': 4.0, 'timestamp': 1368893067, 'title': 'Fido (2006)'}, {'imdbId': 'tt1028528', 'rating': 3.0, 'timestamp': 1368893084, 'title': 'Death Proof (2007)'}]

# %%
instruction = "I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format."

# user_ratings_str3 = eval_set[90]["text"]
# [{"imdbId": "tt101846", "rating": 2.0, "timestamp": 996221356, "title": "F/X2 (a.k.a. F/X 2 - The Deadly Art of Illusion) (1991)"}, {"imdbId": "tt87277", "rating": 3.0, "timestamp": 996259355, "title": "Footloose (1984)"}, {"imdbId": "tt120903", "rating": 2.0, "timestamp": 996212879, "title": "X-Men (2000)"}, {"imdbId": "tt174480", "rating": 2.0, "timestamp": 996217683, "title": "Autumn in New York (2000)"}, {"imdbId": "tt99005", "rating": 5.0, "timestamp": 996256206, "title": "Air America (1990)"}, {"imdbId": "tt191397", "rating": 3.0, "timestamp": 996213058, "title": "Replacements, The (2000)"}, {"imdbId": "tt102510", "rating": 2.0, "timestamp": 996221323, "title": "Naked Gun 2 1/2: The Smell of Fear, The (1991)"}, {"imdbId": "tt204946", "rating": 2.0, "timestamp": 996215785, "title": "Bring It On (2000)"}, {"imdbId": "tt208988", "rating": 4.0, "timestamp": 996217599, "title": "Get Carter (2000)"}, {"imdbId": "tt212338", "rating": 3.0, "timestamp": 996213481, "title": "Meet the Parents (2000)"}]

# %%
def generate_output(idx):
    text = f'''
    ###instruction:
    {instruction}


    user_rating_information:
    {eval_set[idx]["ratings"]}


    '''

    inputs = tokenizer(text, return_tensors="pt").to("cuda")
    outputs = model.generate(
        input_ids=inputs["input_ids"].to("cuda"), 
        attention_mask=inputs["attention_mask"], 
        max_new_tokens=256,
        early_stopping=True,
        pad_token_id=tokenizer.eos_token_id
    )
    output = tokenizer.decode(outputs[0])
    print(f"--- {idx} 번째 eval set 결과---")
    print(output)

# %%
# 사용 예시
for i in range(10):
    generate_output(i) # idx
# Out:
# /home/gpuadmin/anaconda3/envs/llm_test/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:535: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# --- 0 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt107818', 'rating': 2.0, 'timestamp': 1488594826, 'title': 'Philadelphia (1993)'}, {'imdbId': 'tt83658', 'rating': 1.0, 'timestamp': 1489016618, 'title': 'Blade Runner (1982)'}, {'imdbId': 'tt102926', 'rating': 0.5, 'timestamp': 1488332713, 'title': 'Silence of the Lambs, The (1991)'}, {'imdbId': 'tt80684', 'rating': 4.0, 'timestamp': 1488332785, 'title': 'Star Wars: Episode V - The Empire Strikes Back (1980)'}, {'imdbId': 'tt93779', 'rating': 1.5, 'timestamp': 1488594765, 'title': 'Princess Bride, The (1987)'}, {'imdbId': 'tt92005', 'rating': 4.0, 'timestamp': 1488332744, 'title': 'Stand by Me (1986)'}, {'imdbId': 'tt107048', 'rating': 2.5, 'timestamp': 1488332858, 'title': 'Groundhog Day (1993)'}, {'imdbId': 'tt77631', 'rating': 2.0, 'timestamp': 1488333307, 'title': 'Grease (1978)'}, {'imdbId': 'tt116695', 'rating': 3.5, 'timestamp': 1488332764, 'title': 'Jerry Maguire (1996)'}, {'imdbId': 'tt119116', 'rating': 2.0, 'timestamp': 1488333241, 'title': 'Fifth Element, The (1997)'}]
#
#
#
#     Please return the following JSON response:
#     {
#         "movies": [
#             {
#                 "title": "Philadelphia (1993)",
#                 "rating": 2.0
#             },
#             {
#                 "title": "Blade Runner (1982)",
#                 "rating": 1.0
#             },
#             {
#                 "title": "Silence of the Lambs, The (1991)",
#                 "rating": 0.5
#             },
#             {
#                 "title": "Star Wars: Episode V - The Empire Strikes Back (1980)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Princess Bride, The (1987)",
#                 "rating": 1.5
#             },
#             {
#                 "title": "Stand by Me (1986)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Groundhog Day (1993)",
#                 "rating": 2.5
#             },
#             {
#
# --- 1 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt110622', 'rating': 3.0, 'timestamp': 1491095469, 'title': 'Naked Gun 33 1/3: The Final Insult (1994)'}, {'imdbId': 'tt111257', 'rating': 3.5, 'timestamp': 1491091127, 'title': 'Speed (1994)'}, {'imdbId': 'tt111503', 'rating': 3.5, 'timestamp': 1491091137, 'title': 'True Lies (1994)'}, {'imdbId': 'tt106582', 'rating': 2.5, 'timestamp': 1491094563, 'title': 'Cliffhanger (1993)'}, {'imdbId': 'tt106673', 'rating': 2.5, 'timestamp': 1491095417, 'title': 'Dave (1993)'}, {'imdbId': 'tt106697', 'rating': 2.5, 'timestamp': 1491091398, 'title': 'Demolition Man (1993)'}, {'imdbId': 'tt106977', 'rating': 4.0, 'timestamp': 1491092027, 'title': 'Fugitive, The (1993)'}, {'imdbId': 'tt107144', 'rating': 3.5, 'timestamp': 1491095379, 'title': 'Hot Shots! Part Deux (1993)'}, {'imdbId': 'tt107290', 'rating': 4.5, 'timestamp': 1491092073, 'title': 'Jurassic Park (1993)'}, {'imdbId': 'tt107362', 'rating': 2.5, 'timestamp': 1491091881, 'title': 'Last Action Hero (1993)'}]
#
#
#
#     Response:
#     {
#         "movies": [
#             {
#                 "title": "Naked Gun 33 1/3: The Final Insult (1994)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "Speed (1994)",
#                 "rating": 3.5
#             },
#             {
#                 "title": "True Lies (1994)",
#                 "rating": 3.5
#             },
#             {
#                 "title": "Cliffhanger (1993)",
#                 "rating": 2.5
#             },
#             {
#                 "title": "Dave (1993)",
#                 "rating": 2.5
#             },
#             {
#                 "title": "Demolition Man (1993)",
#                 "rating": 2.5
#             },
#             {
#                 "title": "Fugitive, The (1993)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Hot Shots! Part Deux (19
# --- 2 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt2267998', 'rating': 5.0, 'timestamp': 1458636540, 'title': 'Gone Girl (2014)'}, {'imdbId': 'tt2015381', 'rating': 5.0, 'timestamp': 1458635410, 'title': 'Guardians of the Galaxy (2014)'}, {'imdbId': 'tt2911666', 'rating': 4.5, 'timestamp': 1458636615, 'title': 'John Wick (2014)'}, {'imdbId': 'tt2872718', 'rating': 5.0, 'timestamp': 1458636552, 'title': 'Nightcrawler (2014)'}, {'imdbId': 'tt1951265', 'rating': 4.5, 'timestamp': 1458635958, 'title': 'The Hunger Games: Mockingjay - Part 1 (2014)'}, {'imdbId': 'tt369610', 'rating': 3.5, 'timestamp': 1458634708, 'title': 'Jurassic World (2015)'}, {'imdbId': 'tt3316960', 'rating': 4.5, 'timestamp': 1458636954, 'title': 'Still Alice (2014)'}, {'imdbId': 'tt1392190', 'rating': 4.5, 'timestamp': 1458634764, 'title': 'Mad Max: Fury Road (2015)'}, {'imdbId': 'tt2488496', 'rating': 4.5, 'timestamp': 1458634629, 'title': 'Star Wars: Episode VII - The Force Awakens (2015)'}, {'imdbId': 'tt1431045', 'rating': 5.0, 'timestamp': 1458634621, 'title': 'Deadpool (2016)'}]
#
#
#
#     Please provide the list of movies in JSON format.
#
#     Response:
#     [
#         {
#             "imdbId": "tt2267998",
#             "rating": 5.0,
#             "timestamp": 1458636540,
#             "title": "Gone Girl (2014)"
#         },
#         {
#             "imdbId": "tt2015381",
#             "rating": 5.0,
#             "timestamp": 1458635410,
#             "title": "Guardians of the Galaxy (2014)"
#         },
#         {
#             "imdbId": "tt2911666",
#             "rating": 4.5,
#             "timestamp": 1458636615,
#             "title": "John Wick (2014)"
#         },
#         {
#             "imdbId": "tt2872718",
#             "rating": 5.0,
#             "timestamp":
# --- 3 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt110729', 'rating': 3.0, 'timestamp': 841189922, 'title': 'Once Were Warriors (1994)'}, {'imdbId': 'tt110912', 'rating': 5.0, 'timestamp': 841106309, 'title': 'Pulp Fiction (1994)'}, {'imdbId': 'tt110932', 'rating': 3.0, 'timestamp': 841107487, 'title': 'Quiz Show (1994)'}, {'imdbId': 'tt111255', 'rating': 2.0, 'timestamp': 841108045, 'title': 'Specialist, The (1994)'}, {'imdbId': 'tt111161', 'rating': 5.0, 'timestamp': 841106509, 'title': 'Shawshank Redemption, The (1994)'}, {'imdbId': 'tt111149', 'rating': 3.0, 'timestamp': 841109187, 'title': 'Shallow Grave (1994)'}, {'imdbId': 'tt111280', 'rating': 2.0, 'timestamp': 841106509, 'title': 'Star Trek: Generations (1994)'}, {'imdbId': 'tt109040', 'rating': 2.0, 'timestamp': 841106402, 'title': 'Ace Ventura: Pet Detective (1994)'}, {'imdbId': 'tt106339', 'rating': 4.0, 'timestamp': 841141700, 'title': 'Backbeat (1993)'}, {'imdbId': 'tt104779', 'rating': 3.0, 'timestamp': 842744202, 'title': 'Bitter Moon (1992)'}]
#
#
#
#     Please provide the movie title you want to see the rating information for.
#
#     Example: "Once Were Warriors"
#
#     Note: The rating information is in descending order based on the user rating.</s>
# --- 4 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt103859', 'rating': 4.0, 'timestamp': 829828005, 'title': 'Boomerang (1992)'}, {'imdbId': 'tt112442', 'rating': 4.0, 'timestamp': 829828005, 'title': 'Bad Boys (1995)'}, {'imdbId': 'tt112384', 'rating': 5.0, 'timestamp': 829828005, 'title': 'Apollo 13 (1995)'}, {'imdbId': 'tt112462', 'rating': 5.0, 'timestamp': 829828005, 'title': 'Batman Forever (1995)'}, {'imdbId': 'tt112715', 'rating': 2.0, 'timestamp': 829828005, 'title': 'Congo (1995)'}, {'imdbId': 'tt112740', 'rating': 3.0, 'timestamp': 829828005, 'title': 'Crimson Tide (1995)'}, {'imdbId': 'tt112851', 'rating': 5.0, 'timestamp': 829828005, 'title': 'Desperado (1995)'}, {'imdbId': 'tt112864', 'rating': 5.0, 'timestamp': 829828005, 'title': 'Die Hard: With a Vengeance (1995)'}, {'imdbId': 'tt113071', 'rating': 5.0, 'timestamp': 829828006, 'title': 'First Knight (1995)'}, {'imdbId': 'tt114508', 'rating': 2.0, 'timestamp': 829828006, 'title': 'Species (1995)'}]
#
#
#
#     ###response:
#     [
#     {
#         "title": "Boomerang (1992)",
#         "rating": 4.0
#     },
#     {
#         "title": "Bad Boys (1995)",
#         "rating": 4.0
#     },
#     {
#         "title": "Apollo 13 (1995)",
#         "rating": 5.0
#     },
#     {
#         "title": "Batman Forever (1995)",
#         "rating": 5.0
#     },
#     {
#         "title": "Congo (1995)",
#         "rating": 2.0
#     },
#     {
#         "title": "Crimson Tide (1995)",
#         "rating": 3.0
#     },
#     {
#         "title": "Desperado (1995)",
#         "rating": 5.0
#     },
#     {
#         "title": "Die Hard: With a Vengeance (1995)",
#         "rating": 5.0
#
# --- 5 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt1486192', 'rating': 2.0, 'timestamp': 1369660878, 'title': 'Raven, The (2012)'}, {'imdbId': 'tt1307873', 'rating': 1.5, 'timestamp': 1433704205, 'title': 'Big Bang, The (2011)'}, {'imdbId': 'tt1440129', 'rating': 1.0, 'timestamp': 1368282328, 'title': 'Battleship (2012)'}, {'imdbId': 'tt1412386', 'rating': 2.5, 'timestamp': 1361039399, 'title': 'Best Exotic Marigold Hotel, The (2011)'}, {'imdbId': 'tt1195478', 'rating': 2.5, 'timestamp': 1372006763, 'title': 'Five-Year Engagement, The (2012)'}, {'imdbId': 'tt1621045', 'rating': 2.0, 'timestamp': 1369655625, 'title': 'Think Like a Man (2012)'}, {'imdbId': 'tt1077368', 'rating': 2.0, 'timestamp': 1377963360, 'title': 'Dark Shadows (2012)'}, {'imdbId': 'tt1641385', 'rating': 2.5, 'timestamp': 1397303036, 'title': '96 Minutes (2011) '}, {'imdbId': 'tt1645170', 'rating': 3.5, 'timestamp': 1359992764, 'title': 'Dictator, The (2012)'}, {'imdbId': 'tt1409024', 'rating': 2.5, 'timestamp': 1338145121, 'title': 'Men in Black III (M.III.B.) (M.I.B.³) (2012)'}]
#
#
#
#     ###response:
#     [
#         {
#             "title": "Raven, The (2012)",
#             "rating": 2.0
#         },
#         {
#             "title": "Big Bang, The (2011)",
#             "rating": 1.5
#         },
#         {
#             "title": "Battleship (2012)",
#             "rating": 1.0
#         },
#         {
#             "title": "Best Exotic Marigold Hotel, The (2011)",
#             "rating": 2.5
#         },
#         {
#             "title": "Five-Year Engagement, The (2012)",
#             "rating": 2.5
#         },
#         {
#             "title": "Think Like a Man (2012)",
#             "rating": 2.0
#         },
#         {
#             "title": "Dark Shadows (2012)",
#             "rating": 2.0
#         },
#         {
#             "title": "96 Minutes (2011)",
#
# --- 6 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt315327', 'rating': 3.5, 'timestamp': 1158532493, 'title': 'Bruce Almighty (2003)'}, {'imdbId': 'tt266543', 'rating': 4.5, 'timestamp': 1271544881, 'title': 'Finding Nemo (2003)'}, {'imdbId': 'tt317740', 'rating': 3.0, 'timestamp': 1158532836, 'title': 'Italian Job, The (2003)'}, {'imdbId': 'tt322259', 'rating': 3.0, 'timestamp': 1261623858, 'title': '2 Fast 2 Furious (Fast and the Furious 2, The) (2003)'}, {'imdbId': 'tt289043', 'rating': 4.5, 'timestamp': 1158532397, 'title': '28 Days Later (2002)'}, {'imdbId': 'tt305357', 'rating': 2.0, 'timestamp': 1158533715, 'title': "Charlie's Angels: Full Throttle (2003)"}, {'imdbId': 'tt286716', 'rating': 2.5, 'timestamp': 1269121214, 'title': 'Hulk (2003)'}, {'imdbId': 'tt333780', 'rating': 2.5, 'timestamp': 1269123480, 'title': 'Legally Blonde 2: Red, White & Blonde (2003)'}, {'imdbId': 'tt181852', 'rating': 3.0, 'timestamp': 1158532334, 'title': 'Terminator 3: Rise of the Machines (2003)'}, {'imdbId': 'tt325980', 'rating': 5.0, 'timestamp': 1158531197, 'title': 'Pirates of the Caribbean: The Curse of the Black Pearl (2003)'}]
#
#
#
#     Please return the following JSON data:
#     {
#         "movies": [
#             {
#                 "title": "Bruce Almighty (2003)",
#                 "rating": 3.5
#             },
#             {
#                 "title": "Finding Nemo (2003)",
#                 "rating": 4.5
#             },
#             {
#                 "title": "Italian Job, The (2003)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "2 Fast 2 Furious (Fast and the Furious 2, The) (2003)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "28 Days Later (2002)",
#                 "rating": 4.5
#             },
#             {
#                 "title": "Charlie's Angels: Full Throttle (2003)",
#                 "rating": 2.0
#             },
#             {
#                 "title": "Hulk (2003)",
#                 "rating": 2.5
# --- 7 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt315327', 'rating': 3.5, 'timestamp': 1451081261, 'title': 'Bruce Almighty (2003)'}, {'imdbId': 'tt266543', 'rating': 5.0, 'timestamp': 1451080749, 'title': 'Finding Nemo (2003)'}, {'imdbId': 'tt317740', 'rating': 2.5, 'timestamp': 1451080322, 'title': 'Italian Job, The (2003)'}, {'imdbId': 'tt322330', 'rating': 4.0, 'timestamp': 1451080526, 'title': 'Freaky Friday (2003)'}, {'imdbId': 'tt337741', 'rating': 3.0, 'timestamp': 1451080518, 'title': "Something's Gotta Give (2003)"}, {'imdbId': 'tt167260', 'rating': 2.0, 'timestamp': 1451080986, 'title': 'Lord of the Rings: The Return of the King, The (2003)'}, {'imdbId': 'tt338013', 'rating': 3.5, 'timestamp': 1451080832, 'title': 'Eternal Sunshine of the Spotless Mind (2004)'}, {'imdbId': 'tt298148', 'rating': 3.5, 'timestamp': 1451080290, 'title': 'Shrek 2 (2004)'}, {'imdbId': 'tt319262', 'rating': 3.0, 'timestamp': 1451080368, 'title': 'Day After Tomorrow, The (2004)'}, {'imdbId': 'tt304141', 'rating': 5.0, 'timestamp': 1451080270, 'title': 'Harry Potter and the Prisoner of Azkaban (2004)'}]
#
#
#
#     Please provide the corresponding movie title for the given imdbId.
#
#
#     Example:
#     For imdbId 'tt315327', the response should be: "Bruce Almighty (2003)"
#
#
#     JSON format:
#     [
#       {
#         "imdbId": "tt315327",
#         "title": "Bruce Almighty (2003)"
#       },
#       {
#         "imdbId": "tt266543",
#         "title": "Finding Nemo (2003)"
#       },
#       {
#         "imdbId": "tt317740",
#         "title": "Italian Job, The (2003)"
#       },
#       {
#         "imdbId": "tt322330",
#         "title": "Freaky Friday (2003)"
#       },
#       {
#         "imdbId": "tt337741",
#         "title": "Something's Gotta Give (200
# --- 8 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt185183', 'rating': 0.5, 'timestamp': 1449592372, 'title': 'Battlefield Earth (2000)'}, {'imdbId': 'tt217630', 'rating': 2.0, 'timestamp': 1447599468, 'title': 'Loser (2000)'}, {'imdbId': 'tt215129', 'rating': 2.5, 'timestamp': 1466277768, 'title': 'Road Trip (2000)'}, {'imdbId': 'tt120755', 'rating': 3.0, 'timestamp': 1447598137, 'title': 'Mission: Impossible II (2000)'}, {'imdbId': 'tt184894', 'rating': 1.5, 'timestamp': 1449592104, 'title': 'Shanghai Noon (2000)'}, {'imdbId': 'tt208003', 'rating': 1.5, 'timestamp': 1447598875, 'title': "Big Momma's House (2000)"}, {'imdbId': 'tt99582', 'rating': 2.5, 'timestamp': 1450370295, 'title': 'Flatliners (1990)'}, {'imdbId': 'tt84522', 'rating': 1.5, 'timestamp': 1466277401, 'title': "Porky's (1982)"}, {'imdbId': 'tt93894', 'rating': 2.5, 'timestamp': 1450452365, 'title': 'Running Man, The (1987)'}, {'imdbId': 'tt79501', 'rating': 2.0, 'timestamp': 1450452535, 'title': 'Mad Max (1979)'}]
#
#
#
#     Please provide the movie title you want to get the rating information for, and I will return the corresponding rating information in JSON format.
#
#     Example:
#     GetRatingInformation("Battlefield Earth (2000)")
#
#     Output:
#     {
#         "rating": 0.5,
#         "timestamp": 1449592372,
#         "title": "Battlefield Earth (2000)"
#     }
#
#
#
#     Note: The timestamp is the time when the rating was recorded, and the rating is the average user rating given to the movie.
#
#
#     Please let me know if you have any questions or need further assistance.</s>
# --- 9 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt17136', 'rating': 4.0, 'timestamp': 1117354925, 'title': 'Metropolis (1927)'}, {'imdbId': 'tt96874', 'rating': 2.0, 'timestamp': 1095040641, 'title': 'Back to the Future Part II (1989)'}, {'imdbId': 'tt99088', 'rating': 1.5, 'timestamp': 1095040653, 'title': 'Back to the Future Part III (1990)'}, {'imdbId': 'tt47478', 'rating': 4.5, 'timestamp': 1094876098, 'title': 'Seven Samurai (Shichinin no samurai) (1954)'}, {'imdbId': 'tt87182', 'rating': 3.5, 'timestamp': 1094939554, 'title': 'Dune (1984)'}, {'imdbId': 'tt95497', 'rating': 3.5, 'timestamp': 1135054209, 'title': 'Last Temptation of Christ, The (1988)'}, {'imdbId': 'tt91059', 'rating': 3.5, 'timestamp': 1095041324, 'title': 'Flight of the Navigator (1986)'}, {'imdbId': 'tt89853', 'rating': 3.5, 'timestamp': 1142324414, 'title': 'Purple Rose of Cairo, The (1985)'}, {'imdbId': 'tt59113', 'rating': 4.0, 'timestamp': 1094877909, 'title': 'Doctor Zhivago (1965)'}, {'imdbId': 'tt106273', 'rating': 3.5, 'timestamp': 1155628489, 'title': 'And the Band Played On (1993)'}]
#
#
#
#     Please provide the list of movies sorted in descending order of user rating.
#     ```
#     [
#         {
#             "imdbId": "tt17136",
#             "rating": 4.0,
#             "timestamp": 1117354925,
#             "title": "Metropolis (1927)"
#         },
#         {
#             "imdbId": "tt96874",
#             "rating": 2.0,
#             "timestamp": 1095040641,
#             "title": "Back to the Future Part II (1989)"
#         },
#         {
#             "imdbId": "tt99088",
#             "rating": 1.5,
#             "timestamp": 1095040653,
#             "title": "Back to the Future Part III (1990)"
#         },
#         {
#             "imdbId": "tt47478",
#             "rating": 4.5,
#             "timestamp": 109

# %%
# 사용 예시2
for i in range(100, 110):
    generate_output(i) # idx
# Out:
# --- 100 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt163978', 'rating': 3.0, 'timestamp': 1007994972, 'title': 'Beach, The (2000)'}, {'imdbId': 'tt181984', 'rating': 4.0, 'timestamp': 953759895, 'title': 'Boiler Room (2000)'}, {'imdbId': 'tt190138', 'rating': 4.0, 'timestamp': 951169736, 'title': 'Whole Nine Yards, The (2000)'}, {'imdbId': 'tt91217', 'rating': 3.0, 'timestamp': 951756668, 'title': 'Hoosiers (a.k.a. Best Shot) (1986)'}, {'imdbId': 'tt90274', 'rating': 2.0, 'timestamp': 959625116, 'title': 'Volunteers (1985)'}, {'imdbId': 'tt98645', 'rating': 2.0, 'timestamp': 959625102, 'title': "Who's Harry Crumb? (1989)"}, {'imdbId': 'tt92666', 'rating': 3.0, 'timestamp': 1020803145, 'title': 'Blind Date (1987)'}, {'imdbId': 'tt79588', 'rating': 4.0, 'timestamp': 951756789, 'title': 'Muppet Movie, The (1979)'}, {'imdbId': 'tt195685', 'rating': 4.0, 'timestamp': 953759873, 'title': 'Erin Brockovich (2000)'}, {'imdbId': 'tt77975', 'rating': 4.0, 'timestamp': 1007484315, 'title': 'Animal House (1978)'}]
#
#
#
#     Please provide the JSON format output.
#
#
#     Output:
#     [
#     {
#         "title": "Beach, The (2000)",
#         "rating": 3.0
#     },
#     {
#         "title": "Boiler Room (2000)",
#         "rating": 4.0
#     },
#     {
#         "title": "Whole Nine Yards, The (2000)",
#         "rating": 4.0
#     },
#     {
#         "title": "Hoosiers (a.k.a. Best Shot) (1986)",
#         "rating": 3.0
#     },
#     {
#         "title": "Volunteers (1985)",
#         "rating": 2.0
#     },
#     {
#         "title": "Who's Harry Crumb? (1989)",
#         "rating": 2.0
#     },
#     {
#         "title": "Blind Date (1987)",
#         "rating": 3.0
#     },
#     {
#         "
# --- 101 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt43456', 'rating': 3.0, 'timestamp': 965335350, 'title': 'Day the Earth Stood Still, The (1951)'}, {'imdbId': 'tt40897', 'rating': 3.0, 'timestamp': 965661836, 'title': 'Treasure of the Sierra Madre, The (1948)'}, {'imdbId': 'tt88794', 'rating': 4.0, 'timestamp': 965425618, 'title': 'Better Off Dead... (1985)'}, {'imdbId': 'tt81505', 'rating': 5.0, 'timestamp': 965846167, 'title': 'Shining, The (1980)'}, {'imdbId': 'tt92005', 'rating': 5.0, 'timestamp': 965336955, 'title': 'Stand by Me (1986)'}, {'imdbId': 'tt22100', 'rating': 4.0, 'timestamp': 965336611, 'title': 'M (1931)'}, {'imdbId': 'tt92991', 'rating': 4.0, 'timestamp': 965425656, 'title': 'Evil Dead II (Dead by Dawn) (1987)'}, {'imdbId': 'tt57115', 'rating': 5.0, 'timestamp': 965661983, 'title': 'Great Escape, The (1963)'}, {'imdbId': 'tt77416', 'rating': 4.0, 'timestamp': 965846438, 'title': 'Deer Hunter, The (1978)'}, {'imdbId': 'tt107048', 'rating': 5.0, 'timestamp': 965336955, 'title': 'Groundhog Day (1993)'}]
#
#
#
#
#     Response:
#     [
#         {
#             "imdbId": "tt43456",
#             "rating": 3.0,
#             "title": "Day the Earth Stood Still, The (1951)"
#         },
#         {
#             "imdbId": "tt40897",
#             "rating": 3.0,
#             "title": "Treasure of the Sierra Madre, The (1948)"
#         },
#         {
#             "imdbId": "tt88794",
#             "rating": 4.0,
#             "title": "Better Off Dead... (1985)"
#         },
#         {
#             "imdbId": "tt81505",
#             "rating": 5.0,
#             "title": "Shining, The (1980)"
#         },
#         {
#             "imdbId": "tt92005",
#             "rating": 5.0,
#             "title": "Stand by Me (1986)"
#         },
#         {
# --- 102 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt49470', 'rating': 2.0, 'timestamp': 1179108240, 'title': 'Man Who Knew Too Much, The (1956)'}, {'imdbId': 'tt120586', 'rating': 5.0, 'timestamp': 1180330433, 'title': 'American History X (1998)'}, {'imdbId': 'tt131369', 'rating': 3.0, 'timestamp': 1179108054, 'title': 'EDtv (1999)'}, {'imdbId': 'tt133093', 'rating': 4.0, 'timestamp': 1179108880, 'title': 'Matrix, The (1999)'}, {'imdbId': 'tt120797', 'rating': 3.0, 'timestamp': 1179108026, 'title': 'Pushing Tin (1999)'}, {'imdbId': 'tt120915', 'rating': 4.5, 'timestamp': 1179108685, 'title': 'Star Wars: Episode I - The Phantom Menace (1999)'}, {'imdbId': 'tt54033', 'rating': 4.0, 'timestamp': 1179108136, 'title': 'Little Shop of Horrors, The (1960)'}, {'imdbId': 'tt165710', 'rating': 4.0, 'timestamp': 1179108256, 'title': 'Detroit Rock City (1999)'}, {'imdbId': 'tt164181', 'rating': 4.0, 'timestamp': 1179107976, 'title': 'Stir of Echoes (1999)'}, {'imdbId': 'tt137523', 'rating': 4.5, 'timestamp': 1179108929, 'title': 'Fight Club (1999)'}]
#
#
#
#     Please provide the corresponding movie title for each movie based on the user rating information.
#
#
#     Example Output:
#     [
#         {
#             "imdbId": "tt49470",
#             "title": "Man Who Knew Too Much, The (1956)"
#         },
#         {
#             "imdbId": "tt120586",
#             "title": "American History X (1998)"
#         },
#         {
#             "imdbId": "tt131369",
#             "title": "EDtv (1999)"
#         },
#         {
#             "imdbId": "tt133093",
#             "title": "Matrix, The (1999)"
#         },
#         {
#             "imdbId": "tt120797",
#             "title": "Pushing Tin (1999)"
#         },
#         {
#             "imdbId": "tt120915",
#             "title": "Star Wars: Episode I - The Phantom Menace
# --- 103 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt60196', 'rating': 3.5, 'timestamp': 1230497900, 'title': 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)'}, {'imdbId': 'tt66921', 'rating': 3.0, 'timestamp': 1252727946, 'title': 'Clockwork Orange, A (1971)'}, {'imdbId': 'tt56592', 'rating': 3.0, 'timestamp': 1158533138, 'title': 'To Kill a Mockingbird (1962)'}, {'imdbId': 'tt78788', 'rating': 3.0, 'timestamp': 1158532363, 'title': 'Apocalypse Now (1979)'}, {'imdbId': 'tt86190', 'rating': 5.0, 'timestamp': 1158531261, 'title': 'Star Wars: Episode VI - Return of the Jedi (1983)'}, {'imdbId': 'tt99685', 'rating': 3.5, 'timestamp': 1240093011, 'title': 'Goodfellas (1990)'}, {'imdbId': 'tt78748', 'rating': 2.0, 'timestamp': 1158531713, 'title': 'Alien (1979)'}, {'imdbId': 'tt106308', 'rating': 2.5, 'timestamp': 1233381184, 'title': 'Army of Darkness (1993)'}, {'imdbId': 'tt54215', 'rating': 4.5, 'timestamp': 1158532359, 'title': 'Psycho (1960)'}, {'imdbId': 'tt80455', 'rating': 3.0, 'timestamp': 1158532296, 'title': 'Blues Brothers, The (1980)'}]
#
#
#
#     Please provide a JSON response with the following format:
#     {
#         "movies": [
#             {
#                 "title": "Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)",
#                 "rating": 3.5
#             },
#             {
#                 "title": "Clockwork Orange, A (1971)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "To Kill a Mockingbird (1962)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "Apocalypse Now (1979)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "Star Wars: Episode VI - Return of the Jedi (1983)",
#                 "rating": 5.0
#             },
#             {
#                 "title": "Goodfellas (1990)",
#                 "rating": 3.5
#             },
#             {
#                 "title": "Alien (19
# --- 104 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt115742', 'rating': 2.0, 'timestamp': 963179247, 'title': 'Boys (1996)'}, {'imdbId': 'tt117979', 'rating': 3.0, 'timestamp': 954482471, 'title': 'Truth About Cats & Dogs, The (1996)'}, {'imdbId': 'tt112817', 'rating': 1.0, 'timestamp': 953925072, 'title': 'Dead Man (1995)'}, {'imdbId': 'tt115963', 'rating': 3.0, 'timestamp': 963180134, 'title': 'Craft, The (1996)'}, {'imdbId': 'tt112701', 'rating': 4.0, 'timestamp': 963178259, 'title': 'Cold Comfort Farm (1995)'}, {'imdbId': 'tt109592', 'rating': 4.0, 'timestamp': 963178124, 'title': 'Cemetery Man (Dellamorte Dellamore) (1994)'}, {'imdbId': 'tt110480', 'rating': 4.0, 'timestamp': 954481981, 'title': 'Maya Lin: A Strong Clear Vision (1994)'}, {'imdbId': 'tt116594', 'rating': 4.0, 'timestamp': 963179880, 'title': 'I Shot Andy Warhol (1996)'}, {'imdbId': 'tt117951', 'rating': 2.0, 'timestamp': 963179517, 'title': 'Trainspotting (1996)'}, {'imdbId': 'tt117737', 'rating': 4.0, 'timestamp': 963180237, 'title': 'Stealing Beauty (1996)'}]
#
#
#
#     Please provide the JSON output for the given input.
#     """
#     # Sort the list of movies based on their user ratings
#     movies = sorted(user_rating_information, key=lambda x: x['rating'], reverse=True)
#
#     # Create a JSON object with the titles of the movies
#     json_output = {'movies': [x['title'] for x in movies]}
#
#     # Return the JSON output
#     return json_output
#
#
# # Test the function
# print(movie_sorting_function(user_rating_information))
# ```
# This code defines a function `movie_sorting_function` that takes a list of dictionaries representing movie information as input. The function sorts the list of movies based on their user ratings, and then creates a JSON object with the titles of the movies. Finally, the function returns the JSON output.
#
# To test the function, we can call it with the input list of movie information:
# ```
# print(movie_sorting_function(user_rating_information))
# ```
# This will output the following JSON:
# ```
# {
#     "movies": [
#
# --- 105 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt292506', 'rating': 3.5, 'timestamp': 1200952541, 'title': 'Recruit, The (2003)'}, {'imdbId': 'tt302886', 'rating': 2.5, 'timestamp': 1200953469, 'title': 'Old School (2003)'}, {'imdbId': 'tt286499', 'rating': 3.5, 'timestamp': 1200941414, 'title': 'Bend It Like Beckham (2002)'}, {'imdbId': 'tt234215', 'rating': 1.0, 'timestamp': 1200865320, 'title': 'Matrix Reloaded, The (2003)'}, {'imdbId': 'tt315327', 'rating': 3.0, 'timestamp': 1200952932, 'title': 'Bruce Almighty (2003)'}, {'imdbId': 'tt181852', 'rating': 3.5, 'timestamp': 1200953018, 'title': 'Terminator 3: Rise of the Machines (2003)'}, {'imdbId': 'tt266697', 'rating': 4.5, 'timestamp': 1200865291, 'title': 'Kill Bill: Vol. 1 (2003)'}, {'imdbId': 'tt242653', 'rating': 2.5, 'timestamp': 1200870898, 'title': 'Matrix Revolutions, The (2003)'}, {'imdbId': 'tt86567', 'rating': 4.0, 'timestamp': 1200953525, 'title': 'WarGames (1983)'}, {'imdbId': 'tt319061', 'rating': 4.5, 'timestamp': 1200870482, 'title': 'Big Fish (2003)'}]
#
#
#
#     Please return the following JSON:
#     {
#         "movies": [
#             {
#                 "title": "Recruit, The (2003)",
#                 "rating": 3.5
#             },
#             {
#                 "title": "Old School (2003)",
#                 "rating": 2.5
#             },
#             {
#                 "title": "Bend It Like Beckham (2002)",
#                 "rating": 3.5
#             },
#             {
#                 "title": "Kill Bill: Vol. 1 (2003)",
#                 "rating": 4.5
#             },
#             {
#                 "title": "WarGames (1983)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Big Fish (2003)",
#                 "rating": 4.5
#             }
#         ]
#     }
#
#
#
#     Note: The 'timestamp' field is not used in the calculation of the rating.
#     Note: The 'imdbId' field is used to match the movies with their corresponding
# --- 106 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt137523', 'rating': 5.0, 'timestamp': 1298780215, 'title': 'Fight Club (1999)'}, {'imdbId': 'tt86465', 'rating': 3.5, 'timestamp': 1298779447, 'title': 'Trading Places (1983)'}, {'imdbId': 'tt57261', 'rating': 4.0, 'timestamp': 1298779627, 'title': 'Lord of the Flies (1963)'}, {'imdbId': 'tt99871', 'rating': 4.0, 'timestamp': 1298780245, 'title': "Jacob's Ladder (1990)"}, {'imdbId': 'tt83907', 'rating': 4.5, 'timestamp': 1298780084, 'title': 'Evil Dead, The (1981)'}, {'imdbId': 'tt209144', 'rating': 5.0, 'timestamp': 1298780228, 'title': 'Memento (2000)'}, {'imdbId': 'tt289043', 'rating': 5.0, 'timestamp': 1298780098, 'title': '28 Days Later (2002)'}, {'imdbId': 'tt88993', 'rating': 5.0, 'timestamp': 1298779814, 'title': 'Day of the Dead (1985)'}, {'imdbId': 'tt363547', 'rating': 5.0, 'timestamp': 1298780102, 'title': 'Dawn of the Dead (2004)'}, {'imdbId': 'tt77402', 'rating': 5.0, 'timestamp': 1298780068, 'title': 'Dawn of the Dead (1978)'}]
#
#
#
#     Please return the following JSON format:
#     {
#         "movies": [
#             {
#                 "title": "Fight Club (1999)",
#                 "rating": 5.0,
#                 "timestamp": 1298780215
#             },
#             {
#                 "title": "28 Days Later (2002)",
#                 "rating": 5.0,
#                 "timestamp": 1298780228
#             },
#             {
#                 "title": "Memento (2000)",
#                 "rating": 5.0,
#                 "timestamp": 1298780098
#             },
#             {
#                 "title": "Day of the Dead (1985)",
#                 "rating": 5.0,
#                 "timestamp": 1298779814
#             },
#             {
#                 "title": "Dawn of the Dead (2004)",
#                 "rating": 5.0,
#                 "timestamp": 1298780102
#             },
# --- 107 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt459944', 'rating': 5.0, 'timestamp': 1526207948, 'title': 'The Adventures of Sherlock Holmes and Doctor Watson: King of Blackmailers (1980)'}, {'imdbId': 'tt80263', 'rating': 5.0, 'timestamp': 1526207391, 'title': 'The Adventures of Sherlock Holmes and Dr. Watson: Bloody Signature (1979)'}, {'imdbId': 'tt79902', 'rating': 5.0, 'timestamp': 1526207403, 'title': 'Sherlock Holmes and Dr. Watson: Acquaintance (1979)'}, {'imdbId': 'tt3845232', 'rating': 5.0, 'timestamp': 1526206858, 'title': 'Sherlock: The Abominable Bride (2016)'}, {'imdbId': 'tt189160', 'rating': 5.0, 'timestamp': 1526207987, 'title': 'Three from Prostokvashino (1978)'}, {'imdbId': 'tt2948356', 'rating': 4.5, 'timestamp': 1466024376, 'title': 'Zootopia (2016)'}, {'imdbId': 'tt2888046', 'rating': 4.0, 'timestamp': 1526207741, 'title': 'Ip Man 3 (2015)'}, {'imdbId': 'tt5653294', 'rating': 2.5, 'timestamp': 1526208164, 'title': 'The Crew (2016)'}, {'imdbId': 'tt211281', 'rating': 5.0, 'timestamp': 1526207290, 'title': 'The Bremen Town Musicians (1969)'}, {'imdbId': 'tt795176', 'rating': 5.0, 'timestamp': 1526206856, 'title': 'Planet Earth (2006)'}]
#
#
#
#
#     Output:
#     [
#         {
#             "title": "The Adventures of Sherlock Holmes and Doctor Watson: King of Blackmailers (1980)",
#             "rating": 5.0,
#             "timestamp": 1526207948
#         },
#         {
#             "title": "The Adventures of Sherlock Holmes and Dr. Watson: Bloody Signature (1979)",
#             "rating": 5.0,
#             "timestamp": 1526207391
#         },
#         {
#             "title": "Sherlock Holmes and Dr. Watson: Acquaintance (1979)",
#             "rating": 5.0,
#             "timestamp": 1526207403
#         },
#         {
#             "title": "Sherlock: The Abominable Bride (2016)",
#             "rating": 5.0,
#             "timestamp": 1526206858
#         },
#         {
#             "title": "Three from Prostok
# --- 108 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt78748', 'rating': 5.0, 'timestamp': 1033176358, 'title': 'Alien (1979)'}, {'imdbId': 'tt97165', 'rating': 4.0, 'timestamp': 1033174269, 'title': 'Dead Poets Society (1989)'}, {'imdbId': 'tt50212', 'rating': 3.0, 'timestamp': 1033173667, 'title': 'Bridge on the River Kwai, The (1957)'}, {'imdbId': 'tt40897', 'rating': 4.0, 'timestamp': 1033175704, 'title': 'Treasure of the Sierra Madre, The (1948)'}, {'imdbId': 'tt81505', 'rating': 5.0, 'timestamp': 1033176375, 'title': 'Shining, The (1980)'}, {'imdbId': 'tt92005', 'rating': 4.0, 'timestamp': 1033173885, 'title': 'Stand by Me (1986)'}, {'imdbId': 'tt36613', 'rating': 4.0, 'timestamp': 1033173847, 'title': 'Arsenic and Old Lace (1944)'}, {'imdbId': 'tt88763', 'rating': 4.0, 'timestamp': 1033173871, 'title': 'Back to the Future (1985)'}, {'imdbId': 'tt32455', 'rating': 3.0, 'timestamp': 1033174317, 'title': 'Fantasia (1940)'}, {'imdbId': 'tt52618', 'rating': 4.0, 'timestamp': 1033173847, 'title': 'Ben-Hur (1959)'}]
#
#
#
#     Please return the list of movies sorted in descending order of their ratings.
#
#
#     Example Response:
#     [
#     {
#     "imdbId": "tt78748",
#     "rating": 5.0,
#     "timestamp": 1033176358,
#     "title": "Alien (1979)"
#     },
#     {
#     "imdbId": "tt92005",
#     "rating": 4.0,
#     "timestamp": 1033173885,
#     "title": "Stand by Me (1986)"
#     },
#     {
#     "imdbId": "tt88763",
#     "rating": 4.0,
#     "timestamp": 1033173871,
#     "title": "Back to the Future (1985)"
#     },
#     {
#     "imdbId": "tt50212",
#     "rating": 3.0,
#     "timestamp": 1033
# --- 109 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt110912', 'rating': 5.0, 'timestamp': 1435530409, 'title': 'Pulp Fiction (1994)'}, {'imdbId': 'tt111070', 'rating': 4.5, 'timestamp': 1435534302, 'title': 'Santa Clause, The (1994)'}, {'imdbId': 'tt111161', 'rating': 5.0, 'timestamp': 1435523517, 'title': 'Shawshank Redemption, The (1994)'}, {'imdbId': 'tt108550', 'rating': 2.5, 'timestamp': 1435890667, 'title': "What's Eating Gilbert Grape (1993)"}, {'imdbId': 'tt114924', 'rating': 4.0, 'timestamp': 1435533746, 'title': 'While You Were Sleeping (1995)'}, {'imdbId': 'tt110598', 'rating': 3.0, 'timestamp': 1435534564, 'title': "Muriel's Wedding (1994)"}, {'imdbId': 'tt109040', 'rating': 4.0, 'timestamp': 1435533575, 'title': 'Ace Ventura: Pet Detective (1994)'}, {'imdbId': 'tt109045', 'rating': 3.0, 'timestamp': 1435534714, 'title': 'Adventures of Priscilla, Queen of the Desert, The (1994)'}, {'imdbId': 'tt109813', 'rating': 2.0, 'timestamp': 1435978172, 'title': 'Flintstones, The (1994)'}, {'imdbId': 'tt109830', 'rating': 5.0, 'timestamp': 1435523542, 'title': 'Forrest Gump (1994)'}]
#
#
#
#     ###response:
#     [
#         {
#             "title": "Forrest Gump (1994)",
#             "rating": 5.0
#         },
#         {
#             "title": "Shawshank Redemption, The (1994)",
#             "rating": 5.0
#         },
#         {
#             "title": "Pulp Fiction (1994)",
#             "rating": 5.0
#         },
#         {
#             "title": "While You Were Sleeping (1995)",
#             "rating": 4.0
#         },
#         {
#             "title": "Muriel's Wedding (1994)",
#             "rating": 3.0
#         },
#         {
#             "title": "Ace Ventura: Pet Detective (1994)",
#             "rating": 4.0
#         },
#         {
#             "title": "Adventures of Priscilla, Queen of the Desert, The (1994)",
#             "rating": 3.0
#         },
#         {

# %%
# 사용 예시3
for i in range(200, 210):
    generate_output(i) # idx
# Out:
# --- 200 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt106977', 'rating': 4.0, 'timestamp': 975032059, 'title': 'Fugitive, The (1993)'}, {'imdbId': 'tt107206', 'rating': 4.0, 'timestamp': 974943172, 'title': 'In the Line of Fire (1993)'}, {'imdbId': 'tt107207', 'rating': 4.0, 'timestamp': 974942322, 'title': 'In the Name of the Father (1993)'}, {'imdbId': 'tt107616', 'rating': 4.0, 'timestamp': 974942676, 'title': 'Much Ado About Nothing (1993)'}, {'imdbId': 'tt107822', 'rating': 4.0, 'timestamp': 974943132, 'title': 'Piano, The (1993)'}, {'imdbId': 'tt108000', 'rating': 4.0, 'timestamp': 974939593, 'title': 'Ruby in Paradise (1993)'}, {'imdbId': 'tt108052', 'rating': 5.0, 'timestamp': 974938725, 'title': "Schindler's List (1993)"}, {'imdbId': 'tt108122', 'rating': 4.0, 'timestamp': 975032059, 'title': 'Short Cuts (1993)'}, {'imdbId': 'tt83658', 'rating': 3.0, 'timestamp': 974938371, 'title': 'Blade Runner (1982)'}, {'imdbId': 'tt102926', 'rating': 4.0, 'timestamp': 975031129, 'title': 'Silence of the Lambs, The (1991)'}]
#
#
#      Output:
#      {
#         "movies": [
#             {
#                 "title": "Fugitive, The (1993)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "In the Line of Fire (1993)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "In the Name of the Father (1993)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Much Ado About Nothing (1993)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Piano, The (1993)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Ruby in Paradise (1993)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Schindler's List (1993)",
#                 "rating": 5.0
#             },
#             {
#                 "title": "Short Cuts (1993)",
# --- 201 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt61418', 'rating': 3.5, 'timestamp': 1237859157, 'title': 'Bonnie and Clyde (1967)'}, {'imdbId': 'tt92890', 'rating': 3.5, 'timestamp': 1237851304, 'title': 'Dirty Dancing (1987)'}, {'imdbId': 'tt98627', 'rating': 3.0, 'timestamp': 1237851801, 'title': "Weekend at Bernie's (1989)"}, {'imdbId': 'tt83866', 'rating': 2.0, 'timestamp': 1237764434, 'title': 'E.T. the Extra-Terrestrial (1982)'}, {'imdbId': 'tt101775', 'rating': 4.5, 'timestamp': 1237716050, 'title': 'Drop Dead Fred (1991)'}, {'imdbId': 'tt96754', 'rating': 3.5, 'timestamp': 1237709091, 'title': 'Abyss, The (1989)'}, {'imdbId': 'tt71853', 'rating': 4.5, 'timestamp': 1237850747, 'title': 'Monty Python and the Holy Grail (1975)'}, {'imdbId': 'tt101700', 'rating': 3.0, 'timestamp': 1237716046, 'title': 'Delicatessen (1991)'}, {'imdbId': 'tt98724', 'rating': 0.5, 'timestamp': 1237742590, 'title': 'Sex, Lies, and Videotape (1989)'}, {'imdbId': 'tt80684', 'rating': 4.0, 'timestamp': 1237760638, 'title': 'Star Wars: Episode V - The Empire Strikes Back (1980)'}]
#
#
#
#     Please provide the movie title you want to see the rating for, and I will return the corresponding rating information.
#
#
#     Example:
#     Get rating for "Bonnie and Clyde (1967)"
#     Response: { "imdbId": "tt61418", "rating": 3.5, "timestamp": 1237859157, "title": "Bonnie and Clyde (1967)" }
#
#
#     Example:
#     Get rating for "Delicatessen (1991)"
#     Response: { "imdbId": "tt101700", "rating": 3.0, "timestamp": 1237716046, "title": "Delicatessen (1991)" }
#
#
#     Note: The rating information is based on the user input. If the movie title is not found in the list, the response will be empty.
#
#
#     Please let me know if you have any questions or concerns.</s>
# --- 202 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt401855', 'rating': 2.5, 'timestamp': 1498515505, 'title': 'Underworld: Evolution (2006)'}, {'imdbId': 'tt89913', 'rating': 2.5, 'timestamp': 1519264213, 'title': 'Revolution (1985)'}, {'imdbId': 'tt85127', 'rating': 3.0, 'timestamp': 1498525056, 'title': "Project A ('A' gai waak) (1983)"}, {'imdbId': 'tt416496', 'rating': 1.0, 'timestamp': 1498797061, 'title': 'Bandidas (2006)'}, {'imdbId': 'tt114745', 'rating': 2.0, 'timestamp': 1519367934, 'title': 'Tuskegee Airmen, The (1995)'}, {'imdbId': 'tt425598', 'rating': 3.0, 'timestamp': 1498524962, 'title': "Block Party (a.k.a. Dave Chappelle's Block Party) (2005)"}, {'imdbId': 'tt455857', 'rating': 1.0, 'timestamp': 1498503455, 'title': 'When a Stranger Calls (2006)'}, {'imdbId': 'tt449061', 'rating': 3.0, 'timestamp': 1498526369, 'title': 'London (2005)'}, {'imdbId': 'tt404390', 'rating': 2.5, 'timestamp': 1498516841, 'title': 'Running Scared (2006)'}, {'imdbId': 'tt370032', 'rating': 0.5, 'timestamp': 1519178936, 'title': 'Ultraviolet (2006)'}]
#
#
#      Please use the following JSON structure to return the sorted list of movies:
#
#     [
#         {
#             "title": "London (2005)",
#             "rating": 3.0,
#             "timestamp": 1498526369
#         },
#         {
#             "title": "Project A ('A' gai waak) (1983)",
#             "rating": 3.0,
#             "timestamp": 1498525056
#         },
#         {
#             "title": "Underworld: Evolution (2006)",
#             "rating": 2.5,
#             "timestamp": 1498515505
#         },
#         {
#             "title": "Block Party (a.k.a. Dave Chappelle's Block Party) (2005)",
#             "rating": 3.0,
#             "timestamp": 1498524962
#         },
#         {
#             "title": "Revolution (1985)",
#             "rating": 2.5
# --- 203 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt110632', 'rating': 2.0, 'timestamp': 839536984, 'title': 'Natural Born Killers (1994)'}, {'imdbId': 'tt114069', 'rating': 4.0, 'timestamp': 839537112, 'title': 'Outbreak (1995)'}, {'imdbId': 'tt110413', 'rating': 5.0, 'timestamp': 839537372, 'title': 'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)'}, {'imdbId': 'tt110912', 'rating': 5.0, 'timestamp': 839536920, 'title': 'Pulp Fiction (1994)'}, {'imdbId': 'tt111282', 'rating': 3.0, 'timestamp': 839537094, 'title': 'Stargate (1994)'}, {'imdbId': 'tt111161', 'rating': 5.0, 'timestamp': 839537113, 'title': 'Shawshank Redemption, The (1994)'}, {'imdbId': 'tt114614', 'rating': 2.0, 'timestamp': 839537372, 'title': 'Tank Girl (1995)'}, {'imdbId': 'tt111280', 'rating': 5.0, 'timestamp': 839537112, 'title': 'Star Trek: Generations (1994)'}, {'imdbId': 'tt109040', 'rating': 3.0, 'timestamp': 839536954, 'title': 'Ace Ventura: Pet Detective (1994)'}, {'imdbId': 'tt109444', 'rating': 4.0, 'timestamp': 839536954, 'title': 'Clear and Present Danger (1994)'}]
#
#
#
#     Please provide the JSON output in the following format:
#
#     [
#     {
#         "title": "Natural Born Killers (1994)",
#         "rating": 2.0
#     },
#     {
#         "title": "Outbreak (1995)",
#         "rating": 4.0
#     },
#     {
#         "title": "Léon: The Professional (a.k.a. The Professional) (Léon) (1994)",
#         "rating": 5.0
#     },
#     {
#         "title": "Pulp Fiction (1994)",
#         "rating": 5.0
#     },
#     {
#         "title": "Shawshank Redemption, The (1994)",
#         "rating": 5.0
#     },
#     {
#         "title": "Tank Girl (1995)",
#         "rating": 2.0
#     },
#     {
#         "title": "Star Trek: Generations (1994)",
#         "rating": 5.0
#     },
#
# --- 204 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt274812', 'rating': 4.0, 'timestamp': 1493845273, 'title': 'Secretary (2002)'}, {'imdbId': 'tt245429', 'rating': 4.0, 'timestamp': 1493844894, 'title': 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)'}, {'imdbId': 'tt289765', 'rating': 4.0, 'timestamp': 1493847417, 'title': 'Red Dragon (2002)'}, {'imdbId': 'tt310793', 'rating': 4.0, 'timestamp': 1493844958, 'title': 'Bowling for Columbine (2002)'}, {'imdbId': 'tt272338', 'rating': 5.0, 'timestamp': 1493845252, 'title': 'Punch-Drunk Love (2002)'}, {'imdbId': 'tt298130', 'rating': 4.0, 'timestamp': 1493848098, 'title': 'Ring, The (2002)'}, {'imdbId': 'tt82783', 'rating': 5.0, 'timestamp': 1479544766, 'title': 'My Dinner with André (1981)'}, {'imdbId': 'tt295297', 'rating': 4.0, 'timestamp': 1493844904, 'title': 'Harry Potter and the Chamber of Secrets (2002)'}, {'imdbId': 'tt280609', 'rating': 5.0, 'timestamp': 1493843863, 'title': 'Dog Soldiers (2002)'}, {'imdbId': 'tt268126', 'rating': 4.0, 'timestamp': 1493847031, 'title': 'Adaptation (2002)'}]
#
#
#
#     response:
#     [
#         {
#             "title": "Dog Soldiers (2002)",
#             "rating": 5.0,
#             "timestamp": 1493843863
#         },
#         {
#             "title": "Punch-Drunk Love (2002)",
#             "rating": 5.0,
#             "timestamp": 1493845252
#         },
#         {
#             "title": "Adaptation (2002)",
#             "rating": 4.0,
#             "timestamp": 1493847031
#         },
#         {
#             "title": "Secretary (2002)",
#             "rating": 4.0,
#             "timestamp": 1493845273
#         },
#         {
#             "title": "Spirited Away (Sen to Chihiro no kamikakushi) (2001)",
#             "rating": 4.0,
#             "timestamp": 1493844
# --- 205 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt468569', 'rating': 5.0, 'timestamp': 1230750604, 'title': 'Dark Knight, The (2008)'}, {'imdbId': 'tt871426', 'rating': 4.5, 'timestamp': 1230771803, 'title': 'Baby Mama (2008)'}, {'imdbId': 'tt371746', 'rating': 4.5, 'timestamp': 1230750719, 'title': 'Iron Man (2008)'}, {'imdbId': 'tt367882', 'rating': 4.0, 'timestamp': 1230061886, 'title': 'Indiana Jones and the Kingdom of the Crystal Skull (2008)'}, {'imdbId': 'tt441773', 'rating': 3.5, 'timestamp': 1230059701, 'title': 'Kung Fu Panda (2008)'}, {'imdbId': 'tt800080', 'rating': 3.0, 'timestamp': 1243882423, 'title': 'Incredible Hulk, The (2008)'}, {'imdbId': 'tt910970', 'rating': 5.0, 'timestamp': 1230055590, 'title': 'WALL·E (2008)'}, {'imdbId': 'tt493464', 'rating': 2.0, 'timestamp': 1230055193, 'title': 'Wanted (2008)'}, {'imdbId': 'tt409459', 'rating': 2.5, 'timestamp': 1259074273, 'title': 'Watchmen (2009)'}, {'imdbId': 'tt859163', 'rating': 2.5, 'timestamp': 1230670503, 'title': 'Mummy: Tomb of the Dragon Emperor, The (2008)'}]
#
#
#
#     Output:
#     [
#         {
#             "title": "WALL-E (2008)",
#             "rating": 5.0
#         },
#         {
#             "title": "Dark Knight, The (2008)",
#             "rating": 5.0
#         },
#         {
#             "title": "Iron Man (2008)",
#             "rating": 4.5
#         },
#         {
#             "title": "Indiana Jones and the Kingdom of the Crystal Skull (2008)",
#             "rating": 4.0
#         },
#         {
#             "title": "WALL-E (2008)",
#             "rating": 5.0
#         }
#     ]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# --- 206 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt82971', 'rating': 4.0, 'timestamp': 850467408, 'title': 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)'}, {'imdbId': 'tt90605', 'rating': 3.0, 'timestamp': 850467408, 'title': 'Aliens (1986)'}, {'imdbId': 'tt78748', 'rating': 4.0, 'timestamp': 850467425, 'title': 'Alien (1979)'}, {'imdbId': 'tt86197', 'rating': 3.0, 'timestamp': 850467468, 'title': 'Right Stuff, The (1983)'}, {'imdbId': 'tt88247', 'rating': 4.0, 'timestamp': 850467408, 'title': 'Terminator, The (1984)'}, {'imdbId': 'tt97165', 'rating': 3.0, 'timestamp': 850467468, 'title': 'Dead Poets Society (1989)'}, {'imdbId': 'tt107048', 'rating': 2.0, 'timestamp': 850467444, 'title': 'Groundhog Day (1993)'}, {'imdbId': 'tt88763', 'rating': 4.0, 'timestamp': 850467468, 'title': 'Back to the Future (1985)'}, {'imdbId': 'tt72431', 'rating': 5.0, 'timestamp': 850467425, 'title': 'Young Frankenstein (1974)'}, {'imdbId': 'tt32455', 'rating': 5.0, 'timestamp': 850467485, 'title': 'Fantasia (1940)'}]
#
#
#      Please provide the JSON output for the given input.
#
#
#     Note: The input is a list of dictionaries, where each dictionary represents a movie with its imdbId, rating, timestamp, and title. The output should be a JSON array of dictionaries, where each dictionary represents a movie sorted in descending order based on the rating.
#
#
#     Example Output:
#
#     [
#       {
#         "imdbId": "tt82971",
#         "rating": 4.0,
#         "timestamp": 850467408,
#         "title": "Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)"
#       },
#       {
#         "imdbId": "tt78748",
#         "rating": 4.0,
#         "timestamp": 850467425,
#         "title": "Alien (1979)"
#       },
#       {
#         "imdbId": "tt88247",
#         "rating": 4.0,
#         "timestamp":
# --- 207 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt945513', 'rating': 2.0, 'timestamp': 1350912381, 'title': 'Source Code (2011)'}, {'imdbId': 'tt1270798', 'rating': 4.0, 'timestamp': 1350912986, 'title': 'X-Men: First Class (2011)'}, {'imdbId': 'tt848228', 'rating': 5.0, 'timestamp': 1350912191, 'title': 'Avengers, The (2012)'}, {'imdbId': 'tt1306980', 'rating': 3.5, 'timestamp': 1350912896, 'title': '50/50 (2011)'}, {'imdbId': 'tt1637688', 'rating': 4.0, 'timestamp': 1350912405, 'title': 'In Time (2011)'}, {'imdbId': 'tt1392170', 'rating': 4.0, 'timestamp': 1350913120, 'title': 'The Hunger Games (2012)'}, {'imdbId': 'tt1345836', 'rating': 5.0, 'timestamp': 1350912239, 'title': 'Dark Knight Rises, The (2012)'}, {'imdbId': 'tt1515091', 'rating': 4.0, 'timestamp': 1350912696, 'title': 'Sherlock Holmes: A Game of Shadows (2011)'}, {'imdbId': 'tt948470', 'rating': 4.5, 'timestamp': 1350912676, 'title': 'Amazing Spider-Man, The (2012)'}, {'imdbId': 'tt76759', 'rating': 2.5, 'timestamp': 1505400094, 'title': 'Star Wars: Episode IV - A New Hope (1977)'}]
#
#
#
#     Please provide the movie title you want to get the rating for, and I will return the corresponding rating information.
#
#     Example:
#     Get rating for "The Dark Knight Rises"
#     {
#         "rating": 5.0,
#         "timestamp": 1350912239,
#         "title": "The Dark Knight Rises (2012)"
#     }
#
#
#     Note:
#     The timestamp is the time when the rating was recorded, and the title is the movie title associated with the rating.
#
#
#
#
#
#
# </s>
# --- 208 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt283003', 'rating': 4.0, 'timestamp': 1326062061, 'title': 'Spun (2001)'}, {'imdbId': 'tt264395', 'rating': 3.5, 'timestamp': 1326210662, 'title': 'Basic (2003)'}, {'imdbId': 'tt266543', 'rating': 3.0, 'timestamp': 1328288338, 'title': 'Finding Nemo (2003)'}, {'imdbId': 'tt295700', 'rating': 2.5, 'timestamp': 1328296195, 'title': 'Wrong Turn (2003)'}, {'imdbId': 'tt325980', 'rating': 4.0, 'timestamp': 1326106624, 'title': 'Pirates of the Caribbean: The Curse of the Black Pearl (2003)'}, {'imdbId': 'tt266697', 'rating': 3.0, 'timestamp': 1328288200, 'title': 'Kill Bill: Vol. 1 (2003)'}, {'imdbId': 'tt314331', 'rating': 3.5, 'timestamp': 1326061771, 'title': 'Love Actually (2003)'}, {'imdbId': 'tt167260', 'rating': 4.0, 'timestamp': 1328288160, 'title': 'Lord of the Rings: The Return of the King, The (2003)'}, {'imdbId': 'tt289879', 'rating': 4.5, 'timestamp': 1325979910, 'title': 'The Butterfly Effect (2004)'}, {'imdbId': 'tt338013', 'rating': 3.5, 'timestamp': 1326027999, 'title': 'Eternal Sunshine of the Spotless Mind (2004)'}]
#
#
#
#     Please provide the corresponding movie title for the given imdbId.
#
#
#     Example:
#     For imdbId 'tt283003', the response should be:
#     {
#         "title": "Spun (2001)"
#     }
#
#     If there is no movie with the given imdbId, the response should be:
#     {
#         "title": null
#     }
#
#     Note:
#     The imdbId is a unique identifier for each movie, you can find it on the imdb website.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# --- 209 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt4154756', 'rating': 5.0, 'timestamp': 1526165814, 'title': 'Avengers: Infinity War - Part I (2018)'}, {'imdbId': 'tt3501632', 'rating': 5.0, 'timestamp': 1509403737, 'title': 'Thor: Ragnarok (2017)'}, {'imdbId': 'tt3896198', 'rating': 5.0, 'timestamp': 1496617026, 'title': 'Guardians of the Galaxy 2 (2017)'}, {'imdbId': 'tt3498820', 'rating': 5.0, 'timestamp': 1493419810, 'title': 'Captain America: Civil War (2016)'}, {'imdbId': 'tt1211837', 'rating': 5.0, 'timestamp': 1493423214, 'title': 'Doctor Strange (2016)'}, {'imdbId': 'tt3385516', 'rating': 3.0, 'timestamp': 1495476114, 'title': 'X-Men: Apocalypse (2016)'}, {'imdbId': 'tt2250912', 'rating': 5.0, 'timestamp': 1501787006, 'title': 'Untitled Spider-Man Reboot (2017)'}, {'imdbId': 'tt348124', 'rating': 3.0, 'timestamp': 1536874659, 'title': 'Stitch! The Movie (2003)'}, {'imdbId': 'tt2908446', 'rating': 3.0, 'timestamp': 1508109696, 'title': 'Insurgent (2015)'}, {'imdbId': 'tt2820852', 'rating': 3.0, 'timestamp': 1508109656, 'title': 'Furious 7 (2015)'}]
#
#
#
#     Please return the following JSON format:
#     {
#     "movies": [
#         {
#         "title": "Avengers: Infinity War - Part I (2018)",
#         "rating": 5.0,
#         "timestamp": 1526165814
#         },
#         {
#         "title": "Thor: Ragnarok (2017)",
#         "rating": 5.0,
#         "timestamp": 1509403737
#         },
#         {
#         "title": "Guardians of the Galaxy 2 (2017)",
#         "rating": 5.0,
#         "timestamp": 1496617026
#         },
#         {
#         "title": "Captain America: Civil War (2016)",
#         "rating": 5.0,
#         "timestamp": 1493419810
#         },
#         {
#         "title": "Doctor Strange (2016)",
#         "rating": 5.0

# %%
# 사용 예시4
for i in range(700, 710):
    generate_output(i) # idx
# Out:
# --- 700 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt73195', 'rating': 3.5, 'timestamp': 1158532008, 'title': 'Jaws (1975)'}, {'imdbId': 'tt77766', 'rating': 2.5, 'timestamp': 1240093178, 'title': 'Jaws 2 (1978)'}, {'imdbId': 'tt116996', 'rating': 3.0, 'timestamp': 1158532870, 'title': 'Mars Attacks! (1996)'}, {'imdbId': 'tt116695', 'rating': 4.5, 'timestamp': 1271544854, 'title': 'Jerry Maguire (1996)'}, {'imdbId': 'tt117571', 'rating': 2.5, 'timestamp': 1158532360, 'title': 'Scream (1996)'}, {'imdbId': 'tt104691', 'rating': 5.0, 'timestamp': 1158533126, 'title': 'Last of the Mohicans, The (1992)'}, {'imdbId': 'tt117038', 'rating': 2.5, 'timestamp': 1261623578, 'title': 'Michael (1996)'}, {'imdbId': 'tt116250', 'rating': 1.5, 'timestamp': 1261624171, 'title': 'Evita (1996)'}, {'imdbId': 'tt118928', 'rating': 3.0, 'timestamp': 1261623472, 'title': "Dante's Peak (1997)"}, {'imdbId': 'tt118691', 'rating': 3.0, 'timestamp': 1275957920, 'title': 'Beautician and the Beast, The (1997)'}]
#
#
#
#     Please provide the movie title you want to get the rating information for.
#
#
#     Example:
#     GetRatingForMovie("Jaws")
#
#     Output:
#     {
#         "imdbId": "tt73195",
#         "rating": 3.5,
#         "timestamp": 1158532008
#     }
#
#     Note: The output format is in JSON format.
#
#
#     Please let me know if you have any questions.</s>
# --- 701 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt371724', 'rating': 4.0, 'timestamp': 1294441573, 'title': "Hitchhiker's Guide to the Galaxy, The (2005)"}, {'imdbId': 'tt351283', 'rating': 3.0, 'timestamp': 1231167741, 'title': 'Madagascar (2005)'}, {'imdbId': 'tt121164', 'rating': 3.5, 'timestamp': 1357584407, 'title': 'Corpse Bride (2005)'}, {'imdbId': 'tt312004', 'rating': 5.0, 'timestamp': 1130609197, 'title': 'Wallace & Gromit in The Curse of the Were-Rabbit (2005)'}, {'imdbId': 'tt330373', 'rating': 4.5, 'timestamp': 1136331474, 'title': 'Harry Potter and the Goblet of Fire (2005)'}, {'imdbId': 'tt363771', 'rating': 4.5, 'timestamp': 1219930219, 'title': 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)'}, {'imdbId': 'tt356680', 'rating': 3.5, 'timestamp': 1292713922, 'title': 'Family Stone, The (2005)'}, {'imdbId': 'tt434124', 'rating': 4.0, 'timestamp': 1165920392, 'title': 'Kinky Boots (2005)'}, {'imdbId': 'tt449059', 'rating': 4.0, 'timestamp': 1293984190, 'title': 'Little Miss Sunshine (2006)'}, {'imdbId': 'tt436697', 'rating': 4.0, 'timestamp': 1325962571, 'title': 'The Queen (2006)'}]
#
#
#
#     Response:
#     [
#       {
#         "title": "Hitchhiker's Guide to the Galaxy, The (2005)",
#         "rating": 4.0
#       },
#       {
#         "title": "Little Miss Sunshine (2006)",
#         "rating": 4.0
#       },
#       {
#         "title": "Harry Potter and the Goblet of Fire (2005)",
#         "rating": 4.5
#       },
#       {
#         "title": "Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)",
#         "rating": 4.5
#       },
#       {
#         "title": "Kinky Boots (2005)",
#         "rating": 4.0
#       },
#       {
#         "title": "The Queen (2006)",
#         "rating": 4.0
#       }
#     ]
#
#
#     Note: The rating information is in descending order based on the user ratings.</s>
# --- 702 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt218839', 'rating': 2.0, 'timestamp': 1451081803, 'title': 'Best in Show (2000)'}, {'imdbId': 'tt223897', 'rating': 2.5, 'timestamp': 1451081419, 'title': 'Pay It Forward (2000)'}, {'imdbId': 'tt190332', 'rating': 4.0, 'timestamp': 1451081714, 'title': 'Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)'}, {'imdbId': 'tt162222', 'rating': 3.5, 'timestamp': 1451081196, 'title': 'Cast Away (2000)'}, {'imdbId': 'tt212346', 'rating': 3.5, 'timestamp': 1451081815, 'title': 'Miss Congeniality (2000)'}, {'imdbId': 'tt190590', 'rating': 2.0, 'timestamp': 1451081142, 'title': 'O Brother, Where Art Thou? (2000)'}, {'imdbId': 'tt209144', 'rating': 2.0, 'timestamp': 1451081186, 'title': 'Memento (2000)'}, {'imdbId': 'tt126029', 'rating': 4.5, 'timestamp': 1451081180, 'title': 'Shrek (2001)'}, {'imdbId': 'tt244244', 'rating': 0.5, 'timestamp': 1451080438, 'title': 'Swordfish (2001)'}, {'imdbId': 'tt196229', 'rating': 2.0, 'timestamp': 1451081852, 'title': 'Zoolander (2001)'}]
#
#
#
#     Output:
#     {
#         "movies": [
#             {
#                 "title": "Best in Show (2000)",
#                 "rating": 2.0
#             },
#             {
#                 "title": "Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Shrek (2001)",
#                 "rating": 4.5
#             }
#         ]
#     }
#
#
# ### Explanation:
#
# The algorithm will first sort the list of user ratings in descending order based on the rating value. Then, it will iterate through the sorted list and for each movie, it will retrieve the corresponding title and rating information from the `user_rating_information` list. Finally, it will return the sorted list of movies with their corresponding ratings in JSON format.
#
# ### Notes:
#
# * The `imdbId` column is used to uniquely identify each movie.
# * The `rating` column represents the user's rating of the movie on a scale from 0 to
# --- 703 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt347149', 'rating': 3.5, 'timestamp': 1158044012, 'title': "Howl's Moving Castle (Hauru no ugoku shiro) (2004)"}, {'imdbId': 'tt58997', 'rating': 3.5, 'timestamp': 1205565325, 'title': 'Bunny Lake Is Missing (1965)'}, {'imdbId': 'tt374639', 'rating': 3.5, 'timestamp': 1185777069, 'title': 'Incident at Loch Ness (2004)'}, {'imdbId': 'tt292886', 'rating': 2.5, 'timestamp': 1199607371, 'title': '800 Bullets (800 Balas) (2002)'}, {'imdbId': 'tt401792', 'rating': 4.0, 'timestamp': 1137922810, 'title': 'Sin City (2005)'}, {'imdbId': 'tt386342', 'rating': 4.0, 'timestamp': 1164264671, 'title': 'Brothers (Brødre) (2004)'}, {'imdbId': 'tt397065', 'rating': 2.0, 'timestamp': 1183352891, 'title': 'House of Wax (2005)'}, {'imdbId': 'tt89601', 'rating': 2.5, 'timestamp': 1155450082, 'title': 'Mischief (1985)'}, {'imdbId': 'tt372784', 'rating': 4.0, 'timestamp': 1183271835, 'title': 'Batman Begins (2005)'}, {'imdbId': 'tt418819', 'rating': 3.0, 'timestamp': 1166386051, 'title': 'Land of the Dead (2005)'}]
#
#
#
#     Please return the following JSON data:
#     {
#     "movies": [
#     {
#     "title": "Howl's Moving Castle (Hauru no ugoku shiro) (2004)",
#     "rating": 3.5
#     },
#     {
#     "title": "Sin City (2005)",
#     "rating": 4.0
#     },
#     {
#     "title": "Brothers (Brødre) (2004)",
#     "rating": 4.0
#     },
#     {
#     "title": "Batman Begins (2005)",
#     "rating": 4.0
#     },
#     {
#     "title": "Land of the Dead (2005)",
#     "rating": 3.0
#     }
#     ]
#     }
#
#
#
#     Note:
#     * The "title" field contains the title of the movie.
#     * The "rating" field contains the user rating for the movie.
#     * The "timestamp" field contains the date and time when the rating was given.
# --- 704 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt167261', 'rating': 3.5, 'timestamp': 1225479031, 'title': 'Lord of the Rings: The Two Towers, The (2002)'}, {'imdbId': 'tt96283', 'rating': 3.5, 'timestamp': 1225478554, 'title': 'My Neighbor Totoro (Tonari no Totoro) (1988)'}, {'imdbId': 'tt317248', 'rating': 4.0, 'timestamp': 1225478541, 'title': 'City of God (Cidade de Deus) (2002)'}, {'imdbId': 'tt178868', 'rating': 2.0, 'timestamp': 1225476898, 'title': 'Ringu (Ring) (1998)'}, {'imdbId': 'tt92067', 'rating': 3.5, 'timestamp': 1225477583, 'title': 'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)'}, {'imdbId': 'tt266543', 'rating': 4.0, 'timestamp': 1225477517, 'title': 'Finding Nemo (2003)'}, {'imdbId': 'tt335266', 'rating': 4.0, 'timestamp': 1225476658, 'title': 'Lost in Translation (2003)'}, {'imdbId': 'tt340377', 'rating': 3.5, 'timestamp': 1260653384, 'title': 'Station Agent, The (2003)'}, {'imdbId': 'tt319061', 'rating': 4.0, 'timestamp': 1225480961, 'title': 'Big Fish (2003)'}, {'imdbId': 'tt167260', 'rating': 3.5, 'timestamp': 1225479029, 'title': 'Lord of the Rings: The Return of the King, The (2003)'}]
#
#
#
#     Please provide the JSON format response for the above input.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# --- 705 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt307987', 'rating': 4.0, 'timestamp': 1161565696, 'title': 'Bad Santa (2003)'}, {'imdbId': 'tt119167', 'rating': 4.0, 'timestamp': 1161530330, 'title': 'Funny Games (1997)'}, {'imdbId': 'tt99938', 'rating': 3.0, 'timestamp': 1161565636, 'title': 'Kindergarten Cop (1990)'}, {'imdbId': 'tt299977', 'rating': 4.5, 'timestamp': 1161521346, 'title': 'Hero (Ying xiong) (2002)'}, {'imdbId': 'tt298845', 'rating': 4.5, 'timestamp': 1161620632, 'title': 'In America (2002)'}, {'imdbId': 'tt319061', 'rating': 4.0, 'timestamp': 1161520702, 'title': 'Big Fish (2003)'}, {'imdbId': 'tt167260', 'rating': 4.5, 'timestamp': 1161519718, 'title': 'Lord of the Rings: The Return of the King, The (2003)'}, {'imdbId': 'tt340855', 'rating': 4.0, 'timestamp': 1161559732, 'title': 'Monster (2003)'}, {'imdbId': 'tt159365', 'rating': 4.0, 'timestamp': 1161559666, 'title': 'Cold Mountain (2003)'}, {'imdbId': 'tt296042', 'rating': 3.0, 'timestamp': 1161530260, 'title': 'Ichi the Killer (Koroshiya 1) (2001)'}]
#
#
#
#
#     Response:
#     {
#         "movies": [
#             {
#                 "title": "Bad Santa (2003)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Funny Games (1997)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Kindergarten Cop (1990)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "Hero (Ying xiong) (2002)",
#                 "rating": 4.5
#             },
#             {
#                 "title": "In America (2002)",
#                 "rating": 4.5
#             },
#             {
#                 "title": "Big Fish (2003)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Lord of the Rings: The Return of the King, The (2003)",
#                 "rating": 4.5
#             },
#             {
#                 "title": "Monster (200
# --- 706 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt120903', 'rating': 4.0, 'timestamp': 1019125762, 'title': 'X-Men (2000)'}, {'imdbId': 'tt104299', 'rating': 2.0, 'timestamp': 1019133161, 'title': 'Freejack (1992)'}, {'imdbId': 'tt68555', 'rating': 3.0, 'timestamp': 1043577943, 'title': 'Everything You Always Wanted to Know About Sex * But Were Afraid to Ask (1972)'}, {'imdbId': 'tt144528', 'rating': 3.0, 'timestamp': 1041155796, 'title': 'Nutty Professor II: The Klumps (2000)'}, {'imdbId': 'tt164052', 'rating': 2.0, 'timestamp': 1038486175, 'title': 'Hollow Man (2000)'}, {'imdbId': 'tt186566', 'rating': 3.0, 'timestamp': 1021877820, 'title': 'Space Cowboys (2000)'}, {'imdbId': 'tt52646', 'rating': 1.0, 'timestamp': 1035119788, 'title': "Brain That Wouldn't Die, The (1962)"}, {'imdbId': 'tt99005', 'rating': 3.0, 'timestamp': 1097751894, 'title': 'Air America (1990)'}, {'imdbId': 'tt191397', 'rating': 3.0, 'timestamp': 1028529886, 'title': 'Replacements, The (2000)'}, {'imdbId': 'tt95705', 'rating': 5.0, 'timestamp': 1019127430, 'title': 'Naked Gun: From the Files of Police Squad!, The (1988)'}]
#
#
#
#     Please return the following JSON:
#
#     {
#         "movies": [
#             {
#                 "title": "X-Men (2000)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "Naked Gun: From the Files of Police Squad!, The (1988)",
#                 "rating": 5.0
#             },
#             {
#                 "title": "Air America (1990)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "Replacements, The (2000)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "Hollow Man (2000)",
#                 "rating": 2.0
#             },
#             {
#                 "title": "Everything You Always Wanted to Know About Sex * But Were Afraid to Ask (1972)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "Space Cowboys (2000)",
#                 "rating": 3.0
#             },
# --- 707 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt1068680', 'rating': 3.0, 'timestamp': 1324373353, 'title': 'Yes Man (2008)'}, {'imdbId': 'tt1049413', 'rating': 3.5, 'timestamp': 1334940528, 'title': 'Up (2009)'}, {'imdbId': 'tt1119646', 'rating': 3.0, 'timestamp': 1324374205, 'title': 'Hangover, The (2009)'}, {'imdbId': 'tt1022603', 'rating': 4.0, 'timestamp': 1324370902, 'title': '(500) Days of Summer (2009)'}, {'imdbId': 'tt417741', 'rating': 3.0, 'timestamp': 1324376770, 'title': 'Harry Potter and the Half-Blood Prince (2009)'}, {'imdbId': 'tt499549', 'rating': 3.0, 'timestamp': 1324378368, 'title': 'Avatar (2009)'}, {'imdbId': 'tt1130884', 'rating': 3.5, 'timestamp': 1324371080, 'title': 'Shutter Island (2010)'}, {'imdbId': 'tt815236', 'rating': 1.0, 'timestamp': 1328145596, 'title': "She's Out of My League (2010)"}, {'imdbId': 'tt1250777', 'rating': 3.0, 'timestamp': 1328145512, 'title': 'Kick-Ass (2010)'}, {'imdbId': 'tt397612', 'rating': 3.5, 'timestamp': 1328145350, 'title': 'Ricky Gervais Live: Animals (2003)'}]
#
#
#
#     Please provide the JSON format output for the above input.
#
#
#     Output:
#     [
#     {
#         "imdbId": "tt1068680",
#         "rating": 3.0,
#         "timestamp": 1324373353,
#         "title": "Yes Man (2008)"
#     },
#     {
#         "imdbId": "tt1049413",
#         "rating": 3.5,
#         "timestamp": 1334940528,
#         "title": "Up (2009)"
#     },
#     {
#         "imdbId": "tt1119646",
#         "rating": 3.0,
#         "timestamp": 1324374205,
#         "title": "Hangover, The (2009)"
#     },
#     {
#         "imdbId": "tt1022603",
#         "rating": 4.0,
#         "timestamp": 1324
# --- 708 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt71853', 'rating': 5.0, 'timestamp': 1494207080, 'title': 'Monty Python and the Holy Grail (1975)'}, {'imdbId': 'tt108598', 'rating': 3.0, 'timestamp': 1494210553, 'title': 'Wallace & Gromit: The Wrong Trousers (1993)'}, {'imdbId': 'tt73486', 'rating': 5.0, 'timestamp': 1494207087, 'title': "One Flew Over the Cuckoo's Nest (1975)"}, {'imdbId': 'tt80684', 'rating': 5.0, 'timestamp': 1494206982, 'title': 'Star Wars: Episode V - The Empire Strikes Back (1980)'}, {'imdbId': 'tt93779', 'rating': 4.0, 'timestamp': 1494207070, 'title': 'Princess Bride, The (1987)'}, {'imdbId': 'tt82971', 'rating': 5.0, 'timestamp': 1494210760, 'title': 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)'}, {'imdbId': 'tt90605', 'rating': 4.0, 'timestamp': 1494211035, 'title': 'Aliens (1986)'}, {'imdbId': 'tt60196', 'rating': 2.5, 'timestamp': 1494210392, 'title': 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)'}, {'imdbId': 'tt50083', 'rating': 5.0, 'timestamp': 1494210997, 'title': '12 Angry Men (1957)'}, {'imdbId': 'tt66921', 'rating': 4.5, 'timestamp': 1494207085, 'title': 'Clockwork Orange, A (1971)'}]
#
#
#
#     Output:
#     [
#         {
#             "title": "Monty Python and the Holy Grail (1975)",
#             "rating": 5.0
#         },
#         {
#             "title": "Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)",
#             "rating": 5.0
#         },
#         {
#             "title": "Star Wars: Episode V - The Empire Strikes Back (1980)",
#             "rating": 5.0
#         },
#         {
#             "title": "Aliens (1986)",
#             "rating": 4.0
#         },
#         {
#             "title": "12 Angry Men (1957)",
#             "rating": 5.0
#         },
#         {
#             "title": "Clockwork Orange, A (1971)",
#             "rating": 4.5
#         }
#     ]
#
#
#
# In this example, the output is a JSON array of objects, where each object represents a movie and contains the title and
# --- 709 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt119116', 'rating': 4.0, 'timestamp': 1111623379, 'title': 'Fifth Element, The (1997)'}, {'imdbId': 'tt119567', 'rating': 2.0, 'timestamp': 1111523279, 'title': 'Lost World: Jurassic Park, The (1997)'}, {'imdbId': 'tt118880', 'rating': 1.5, 'timestamp': 1111623190, 'title': 'Con Air (1997)'}, {'imdbId': 'tt119654', 'rating': 1.5, 'timestamp': 1111525503, 'title': 'Men in Black (a.k.a. MIB) (1997)'}, {'imdbId': 'tt82198', 'rating': 2.5, 'timestamp': 1111524524, 'title': 'Conan the Barbarian (1982)'}, {'imdbId': 'tt120177', 'rating': 3.0, 'timestamp': 1111524014, 'title': 'Spawn (1997)'}, {'imdbId': 'tt118883', 'rating': 2.5, 'timestamp': 1111623396, 'title': 'Conspiracy Theory (1997)'}, {'imdbId': 'tt118571', 'rating': 3.0, 'timestamp': 1111623930, 'title': 'Air Force One (1997)'}, {'imdbId': 'tt118842', 'rating': 5.0, 'timestamp': 1111487474, 'title': 'Chasing Amy (1997)'}, {'imdbId': 'tt119164', 'rating': 3.0, 'timestamp': 1111524312, 'title': 'Full Monty, The (1997)'}]
#
#
#
#     Please return the list of movies sorted in descending order of user rating.
#
#
#     JSON response:
#     [
#     {
#         "imdbId": "tt119116",
#         "rating": 4.0,
#         "timestamp": 1111623379,
#         "title": "Fifth Element, The (1997)"
#     },
#     {
#         "imdbId": "tt119567",
#         "rating": 2.0,
#         "timestamp": 1111523279,
#         "title": "Lost World: Jurassic Park, The (1997)"
#     },
#     {
#         "imdbId": "tt118880",
#         "rating": 1.5,
#         "timestamp": 1111623190,
#         "title": "Con Air (1997)"
#     },
#     {
#         "imdbId": "tt119654",
#         "rating": 1.

# %%
# 사용 예시5
for i in range(950, 960):
    generate_output(i) # idx
# Out:
# --- 950 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt297884', 'rating': 4.0, 'timestamp': 1043177830, 'title': 'Far from Heaven (2002)'}, {'imdbId': 'tt295297', 'rating': 3.0, 'timestamp': 1043177872, 'title': 'Harry Potter and the Chamber of Secrets (2002)'}, {'imdbId': 'tt246460', 'rating': 2.0, 'timestamp': 1043177906, 'title': 'Die Another Day (2002)'}, {'imdbId': 'tt307479', 'rating': 4.0, 'timestamp': 1043177889, 'title': 'Solaris (2002)'}, {'imdbId': 'tt268126', 'rating': 4.0, 'timestamp': 1043177872, 'title': 'Adaptation (2002)'}, {'imdbId': 'tt83629', 'rating': 2.0, 'timestamp': 1043176423, 'title': 'Beast Within, The (1982)'}, {'imdbId': 'tt257360', 'rating': 4.0, 'timestamp': 1043177830, 'title': 'About Schmidt (2002)'}, {'imdbId': 'tt167261', 'rating': 5.0, 'timestamp': 1043177848, 'title': 'Lord of the Rings: The Two Towers, The (2002)'}, {'imdbId': 'tt217505', 'rating': 5.0, 'timestamp': 1043177889, 'title': 'Gangs of New York (2002)'}, {'imdbId': 'tt264464', 'rating': 4.0, 'timestamp': 1043177872, 'title': 'Catch Me If You Can (2002)'}]
#
#
#
#
#     Output:
#     [
#         {
#             "title": "Solaris (2002)",
#             "rating": 4.0
#         },
#         {
#             "title": "Adaptation (2002)",
#             "rating": 4.0
#         },
#         {
#             "title": "About Schmidt (2002)",
#             "rating": 4.0
#         },
#         {
#             "title": "Lord of the Rings: The Two Towers, The (2002)",
#             "rating": 5.0
#         },
#         {
#             "title": "Gangs of New York (2002)",
#             "rating": 5.0
#         },
#         {
#             "title": "Catch Me If You Can (2002)",
#             "rating": 4.0
#         }
#     ]
#
#
#     Note:
#     The output is in JSON format, where each movie is represented as an object with the following properties:
#     * "title": the title of the movie
#     * "rating": the user rating for the
# --- 951 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt120630', 'rating': 3.0, 'timestamp': 965702777, 'title': 'Chicken Run (2000)'}, {'imdbId': 'tt183505', 'rating': 3.0, 'timestamp': 965702843, 'title': 'Me, Myself & Irene (2000)'}, {'imdbId': 'tt131704', 'rating': 4.0, 'timestamp': 965702777, 'title': 'Adventures of Rocky and Bullwinkle, The (2000)'}, {'imdbId': 'tt89118', 'rating': 3.0, 'timestamp': 965711184, 'title': 'F/X (1986)'}, {'imdbId': 'tt87175', 'rating': 2.0, 'timestamp': 965703915, 'title': 'Dreamscape (1984)'}, {'imdbId': 'tt219854', 'rating': 2.0, 'timestamp': 965702923, 'title': 'Kid, The (2000)'}, {'imdbId': 'tt175142', 'rating': 1.0, 'timestamp': 965702905, 'title': 'Scary Movie (2000)'}, {'imdbId': 'tt120903', 'rating': 4.0, 'timestamp': 965702777, 'title': 'X-Men (2000)'}, {'imdbId': 'tt163676', 'rating': 3.0, 'timestamp': 965702954, 'title': 'In Crowd, The (2000)'}, {'imdbId': 'tt161081', 'rating': 2.0, 'timestamp': 965702843, 'title': 'What Lies Beneath (2000)'}]
#
#
#
#     Output:
#     {
#         "movies": [
#             {
#                 "title": "Chicken Run (2000)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "Me, Myself & Irene (2000)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "Adventures of Rocky and Bullwinkle, The (2000)",
#                 "rating": 4.0
#             },
#             {
#                 "title": "F/X (1986)",
#                 "rating": 3.0
#             },
#             {
#                 "title": "Dreamscape (1984)",
#                 "rating": 2.0
#             },
#             {
#                 "title": "Kid, The (2000)",
#                 "rating": 2.0
#             },
#             {
#                 "title": "Scary Movie (2000)",
#                 "rating": 1.0
#             },
#             {
#                 "title": "X-Men (200
# --- 952 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt58150', 'rating': 3.5, 'timestamp': 1494211000, 'title': 'Goldfinger (1964)'}, {'imdbId': 'tt137523', 'rating': 5.0, 'timestamp': 1494206967, 'title': 'Fight Club (1999)'}, {'imdbId': 'tt96438', 'rating': 2.0, 'timestamp': 1494211291, 'title': 'Who Framed Roger Rabbit? (1988)'}, {'imdbId': 'tt120601', 'rating': 1.0, 'timestamp': 1494211922, 'title': 'Being John Malkovich (1999)'}, {'imdbId': 'tt70608', 'rating': 2.5, 'timestamp': 1494210990, 'title': 'Robin Hood (1973)'}, {'imdbId': 'tt96061', 'rating': 3.5, 'timestamp': 1494211954, 'title': 'Scrooged (1988)'}, {'imdbId': 'tt120363', 'rating': 4.5, 'timestamp': 1494210386, 'title': 'Toy Story 2 (1999)'}, {'imdbId': 'tt177789', 'rating': 1.5, 'timestamp': 1494210896, 'title': 'Galaxy Quest (1999)'}, {'imdbId': 'tt144117', 'rating': 3.0, 'timestamp': 1494211143, 'title': 'Boondock Saints, The (2000)'}, {'imdbId': 'tt77975', 'rating': 1.0, 'timestamp': 1494211272, 'title': 'Animal House (1978)'}]
#
#
#
#     Please provide the JSON output for the above input.
#
#
# Note: The timestamp value represents the date and time when the user rated the movie.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# --- 953 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt137523', 'rating': 5.0, 'timestamp': 1461865568, 'title': 'Fight Club (1999)'}, {'imdbId': 'tt120689', 'rating': 4.5, 'timestamp': 1461865714, 'title': 'Green Mile, The (1999)'}, {'imdbId': 'tt195685', 'rating': 3.0, 'timestamp': 1461865932, 'title': 'Erin Brockovich (2000)'}, {'imdbId': 'tt100758', 'rating': 0.5, 'timestamp': 1461868557, 'title': 'Teenage Mutant Ninja Turtles (1990)'}, {'imdbId': 'tt209144', 'rating': 3.5, 'timestamp': 1461865764, 'title': 'Memento (2000)'}, {'imdbId': 'tt243155', 'rating': 0.5, 'timestamp': 1461868092, 'title': "Bridget Jones's Diary (2001)"}, {'imdbId': 'tt96928', 'rating': 4.0, 'timestamp': 1461868100, 'title': "Bill & Ted's Excellent Adventure (1989)"}, {'imdbId': 'tt166924', 'rating': 3.0, 'timestamp': 1461865599, 'title': 'Mulholland Drive (2001)'}, {'imdbId': 'tt246578', 'rating': 5.0, 'timestamp': 1461866001, 'title': 'Donnie Darko (2001)'}, {'imdbId': 'tt120737', 'rating': 5.0, 'timestamp': 1461865574, 'title': 'Lord of the Rings: The Fellowship of the Ring, The (2001)'}]
#
#
#
#     Please provide the JSON output in the following format:
#     [
#         {
#             "title": "Fight Club (1999)",
#             "rating": 5.0,
#             "timestamp": 1461865568
#         },
#         {
#             "title": "Green Mile, The (1999)",
#             "rating": 4.5,
#             "timestamp": 1461865714
#         },
#         {
#             "title": "Memento (2000)",
#             "rating": 3.5,
#             "timestamp": 1461865764
#         },
#         {
#             "title": "Bill & Ted's Excellent Adventure (1989)",
#             "rating": 4.0,
#             "timestamp": 1461868100
#         },
#         {
#             "title": "Mulholland Drive (2001)",
#             "rating": 3.0,
#             "timestamp": 146186559
# --- 954 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt4116284', 'rating': 5.0, 'timestamp': 1508436102, 'title': 'The Lego Batman Movie (2017)'}, {'imdbId': 'tt4425200', 'rating': 5.0, 'timestamp': 1501786943, 'title': 'John Wick: Chapter Two (2017)'}, {'imdbId': 'tt3315342', 'rating': 5.0, 'timestamp': 1493419798, 'title': 'Logan (2017)'}, {'imdbId': 'tt3731562', 'rating': 4.0, 'timestamp': 1508200864, 'title': 'Kong: Skull Island (2017)'}, {'imdbId': 'tt3717490', 'rating': 3.0, 'timestamp': 1508110353, 'title': 'Power Rangers (2017)'}, {'imdbId': 'tt2316204', 'rating': 2.0, 'timestamp': 1494635338, 'title': 'Alien: Covenant (2017)'}, {'imdbId': 'tt3890160', 'rating': 4.0, 'timestamp': 1508109046, 'title': 'Baby Driver (2017)'}, {'imdbId': 'tt117880', 'rating': 4.0, 'timestamp': 1494803341, 'title': 'T2 3-D: Battle Across Time (1996)'}, {'imdbId': 'tt366177', 'rating': 5.0, 'timestamp': 1536875315, 'title': 'A Detective Story (2003)'}, {'imdbId': 'tt350934', 'rating': 3.5, 'timestamp': 1508436819, 'title': 'Final Flight of the Osiris (2003)'}]
#
#
#
#     Please return the following JSON format:
#     {
#         "movies": [
#             {
#                 "title": "The Lego Batman Movie (2017)",
#                 "rating": 5.0,
#                 "timestamp": 1508436102
#             },
#             {
#                 "title": "John Wick: Chapter Two (2017)",
#                 "rating": 5.0,
#                 "timestamp": 1501786943
#             },
#             {
#                 "title": "Logan (2017)",
#                 "rating": 5.0,
#                 "timestamp": 1493419798
#             },
#             {
#                 "title": "Kong: Skull Island (2017)",
#                 "rating": 4.0,
#                 "timestamp": 1508200864
#             },
#             {
#                 "title": "Baby Driver (2017)",
#                 "rating": 4.0,
#                 "timestamp": 1508109
# --- 955 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt443543', 'rating': 1.5, 'timestamp': 1162175482, 'title': 'Illusionist, The (2006)'}, {'imdbId': 'tt427969', 'rating': 3.0, 'timestamp': 1175998131, 'title': 'Hollywoodland (2006)'}, {'imdbId': 'tt443453', 'rating': 3.0, 'timestamp': 1175998298, 'title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006)'}, {'imdbId': 'tt407887', 'rating': 4.5, 'timestamp': 1162175590, 'title': 'Departed, The (2006)'}, {'imdbId': 'tt206634', 'rating': 3.0, 'timestamp': 1175998177, 'title': 'Children of Men (2006)'}, {'imdbId': 'tt482571', 'rating': 4.0, 'timestamp': 1162175473, 'title': 'Prestige, The (2006)'}, {'imdbId': 'tt381061', 'rating': 4.0, 'timestamp': 1175998201, 'title': 'Casino Royale (2006)'}, {'imdbId': 'tt416449', 'rating': 5.0, 'timestamp': 1175998171, 'title': '300 (2007)'}, {'imdbId': 'tt112573', 'rating': 3.5, 'timestamp': 1436943893, 'title': 'Braveheart (1995)'}, {'imdbId': 'tt111161', 'rating': 5.0, 'timestamp': 1436943744, 'title': 'Shawshank Redemption, The (1994)'}]
#
#
#
#     Please provide the JSON output for the descending order movie list based on user ratings.
#     ```
#     [
#         {
#             "title": "300 (2007)",
#             "rating": 5.0,
#             "timestamp": 1175998171
#         },
#         {
#             "title": "Shawshank Redemption, The (1994)",
#             "rating": 5.0,
#             "timestamp": 1436943744
#         },
#         {
#             "title": "Braveheart (1995)",
#             "rating": 3.5,
#             "timestamp": 1436943893
#         },
#         {
#             "title": "Casino Royale (2006)",
#             "rating": 4.0,
#             "timestamp": 1175998201
#         },
#         {
#             "title": "Prestige, The (2006)",
#             "rating": 4.0,
#             "timestamp":
# --- 956 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt114746', 'rating': 5.0, 'timestamp': 861812794, 'title': 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)'}, {'imdbId': 'tt113862', 'rating': 2.0, 'timestamp': 861812794, 'title': "Mr. Holland's Opus (1995)"}, {'imdbId': 'tt115683', 'rating': 3.0, 'timestamp': 861812976, 'title': 'Bio-Dome (1996)'}, {'imdbId': 'tt115759', 'rating': 3.0, 'timestamp': 861812794, 'title': 'Broken Arrow (1996)'}, {'imdbId': 'tt116483', 'rating': 4.0, 'timestamp': 861812866, 'title': 'Happy Gilmore (1996)'}, {'imdbId': 'tt113326', 'rating': 3.0, 'timestamp': 861812866, 'title': 'Rumble in the Bronx (Hont faan kui) (1995)'}, {'imdbId': 'tt76759', 'rating': 4.0, 'timestamp': 861812827, 'title': 'Star Wars: Episode IV - A New Hope (1977)'}, {'imdbId': 'tt117608', 'rating': 3.0, 'timestamp': 861812892, 'title': 'Sgt. Bilko (1996)'}, {'imdbId': 'tt116136', 'rating': 4.0, 'timestamp': 861812866, 'title': 'Dragonheart (1996)'}, {'imdbId': 'tt116168', 'rating': 3.0, 'timestamp': 861813207, 'title': 'Eddie (1996)'}]
#
#
#
#     Please provide the JSON output:
#     [
#       {
#         "title": "Twelve Monkeys (a.k.a. 12 Monkeys) (1995)",
#         "rating": 5.0
#       },
#       {
#         "title": "Happy Gilmore (1996)",
#         "rating": 4.0
#       },
#       {
#         "title": "Dragonheart (1996)",
#         "rating": 4.0
#       },
#       {
#         "title": "Star Wars: Episode IV - A New Hope (1977)",
#         "rating": 4.0
#       },
#       {
#         "title": "Sgt. Bilko (1996)",
#         "rating": 3.0
#       },
#       {
#         "title": "Broken Arrow (1996)",
#         "rating": 3.0
#       },
#       {
#         "title": "Rumble in the Bronx (Hont faan kui) (1995)",
#         "rating": 3.0
#
# --- 957 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt120737', 'rating': 4.0, 'timestamp': 1391350311, 'title': 'Lord of the Rings: The Fellowship of the Ring, The (2001)'}, {'imdbId': 'tt268978', 'rating': 4.5, 'timestamp': 1391350753, 'title': 'Beautiful Mind, A (2001)'}, {'imdbId': 'tt284490', 'rating': 1.5, 'timestamp': 1391352491, 'title': 'Showtime (2002)'}, {'imdbId': 'tt245574', 'rating': 3.0, 'timestamp': 1391350682, 'title': 'And Your Mother Too (Y tu mamá también) (2001)'}, {'imdbId': 'tt120912', 'rating': 3.0, 'timestamp': 1391352108, 'title': 'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (2002)'}, {'imdbId': 'tt295701', 'rating': 2.5, 'timestamp': 1391346778, 'title': 'xXx (2002)'}, {'imdbId': 'tt180052', 'rating': 2.5, 'timestamp': 1391353041, 'title': 'Adventures of Pluto Nash, The (2002)'}, {'imdbId': 'tt102059', 'rating': 2.5, 'timestamp': 1391352961, 'title': 'Hot Shots! (1991)'}, {'imdbId': 'tt82045', 'rating': 2.5, 'timestamp': 1391352667, 'title': 'Banana Joe (1981)'}, {'imdbId': 'tt167261', 'rating': 3.5, 'timestamp': 1391350288, 'title': 'Lord of the Rings: The Two Towers, The (2002)'}]
#
#
#      Please provide the JSON response in the format:
#      {
#      "movies": [
#      {
#      "title": "Lord of the Rings: The Fellowship of the Ring, The",
#      "rating": 4.0,
#      "timestamp": 1391350311
#      },
#      {
#      "title": "Beautiful Mind, A",
#      "rating": 4.5,
#      "timestamp": 1391350753
#      },
#      {
#      "title": "Lord of the Rings: The Two Towers, The",
#      "rating": 3.5,
#      "timestamp": 1391350288
#      },
#      // ...
#      ]
#      }
#
#
#     Please provide the JSON response in the format above.
#     ```
#     {
#     "movies": [
#     {
#     "title": "Lord of the Rings: The Fellowship of the Ring, The",
#     "rating": 4.0,
#     "timestamp": 13913503
# --- 958 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt38650', 'rating': 5.0, 'timestamp': 997812874, 'title': "It's a Wonderful Life (1946)"}, {'imdbId': 'tt58331', 'rating': 5.0, 'timestamp': 997812099, 'title': 'Mary Poppins (1964)'}, {'imdbId': 'tt83866', 'rating': 5.0, 'timestamp': 997811632, 'title': 'E.T. the Extra-Terrestrial (1982)'}, {'imdbId': 'tt71853', 'rating': 3.0, 'timestamp': 997811251, 'title': 'Monty Python and the Holy Grail (1975)'}, {'imdbId': 'tt80684', 'rating': 4.0, 'timestamp': 997812715, 'title': 'Star Wars: Episode V - The Empire Strikes Back (1980)'}, {'imdbId': 'tt82971', 'rating': 5.0, 'timestamp': 997811126, 'title': 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)'}, {'imdbId': 'tt56592', 'rating': 5.0, 'timestamp': 997811156, 'title': 'To Kill a Mockingbird (1962)'}, {'imdbId': 'tt54215', 'rating': 4.0, 'timestamp': 997811331, 'title': 'Psycho (1960)'}, {'imdbId': 'tt71562', 'rating': 4.0, 'timestamp': 997812715, 'title': 'Godfather: Part II, The (1974)'}, {'imdbId': 'tt97165', 'rating': 5.0, 'timestamp': 997812656, 'title': 'Dead Poets Society (1989)'}]
#
#
#
#     Please return the sorted list of movies in JSON format as follows:
#     [
#         {
#             "title": "Dead Poets Society (1989)",
#             "rating": 5.0,
#             "timestamp": 997812656
#         },
#         {
#             "title": "It's a Wonderful Life (1946)",
#             "rating": 5.0,
#             "timestamp": 997812874
#         },
#         {
#             "title": "Monty Python and the Holy Grail (1975)",
#             "rating": 3.0,
#             "timestamp": 997811251
#         },
#         {
#             "title": "Psycho (1960)",
#             "rating": 4.0,
#             "timestamp": 997811331
#         },
#         {
#             "title": "Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)",
#             "rating":
# --- 959 번째 eval set 결과---
# <s>
#     ###instruction:
#     I will sort the movie list in descending order based on user rating information. I will show the title for the corresponding movie. It must return in JSON format.
#
#
#     user_rating_information:
#     [{'imdbId': 'tt71807', 'rating': 4.0, 'timestamp': 1197015062, 'title': 'Man with the Golden Gun, The (1974)'}, {'imdbId': 'tt208003', 'rating': 2.5, 'timestamp': 1171829693, 'title': "Big Momma's House (2000)"}, {'imdbId': 'tt81318', 'rating': 3.0, 'timestamp': 1288173019, 'title': 'City of the Living Dead (a.k.a. Gates of Hell, The) (Paura nella città dei morti viventi) (1980)'}, {'imdbId': 'tt71230', 'rating': 4.0, 'timestamp': 1253914675, 'title': 'Blazing Saddles (1974)'}, {'imdbId': 'tt74486', 'rating': 4.0, 'timestamp': 1217201110, 'title': 'Eraserhead (1977)'}, {'imdbId': 'tt59578', 'rating': 4.0, 'timestamp': 1171409148, 'title': 'For a Few Dollars More (Per qualche dollaro in più) (1965)'}, {'imdbId': 'tt90190', 'rating': 3.5, 'timestamp': 1172026169, 'title': 'Toxic Avenger, The (1985)'}, {'imdbId': 'tt91630', 'rating': 4.0, 'timestamp': 1172458556, 'title': 'Night of the Creeps (1986)'}, {'imdbId': 'tt100403', 'rating': 2.5, 'timestamp': 1171785573, 'title': 'Predator 2 (1990)'}, {'imdbId': 'tt93894', 'rating': 3.5, 'timestamp': 1171785668, 'title': 'Running Man, The (1987)'}]
#
#
#
#     Please provide the list of movies in descending order of their ratings.
#     ```
#     [
#         {
#             "title": "Blazing Saddles (1974)",
#             "rating": 4.0
#         },
#         {
#             "title": "City of the Living Dead (a.k.a. Gates of Hell, The) (Paura nella città dei morti viventi) (1980)",
#             "rating": 3.0
#         },
#         {
#             "title": "Eraserhead (1977)",
#             "rating": 4.0
#         },
#         {
#             "title": "For a Few Dollars More (Per qualche dollaro in più) (1965)",
#             "rating": 4.0
#         },
#         {
#             "title": "Night of the Creeps (1986)",
#             "rating": 4.0
#         },
#         {
#             "title": "Predator 2 (1990)",
#             "rating": 2.5
#         },
#         {

# %%
# # {instruction}

# text = f'''
# ###instruction:
# {instruction}


# user_rating_information:
# {eval_set[90]["text"]}


# '''
# inputs = tokenizer(text, return_tensors="pt").to("cuda")
# outputs = model.generate(
#     input_ids=inputs["input_ids"].to("cuda"), 
#     attention_mask=inputs["attention_mask"], 
#     max_new_tokens=256,
#     early_stopping=True,
#     pad_token_id=tokenizer.eos_token_id
# )
# output = tokenizer.decode(outputs[0])
# print(output)
