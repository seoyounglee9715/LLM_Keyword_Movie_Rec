# %%
from sentence_transformers import SentenceTransformer, util
sentences = ["I'm happy", "I'm full of happiness"]

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

#Compute embedding for both lists
embedding_1= model.encode(sentences[0], convert_to_tensor=True)
embedding_2 = model.encode(sentences[1], convert_to_tensor=True)

util.pytorch_cos_sim(embedding_1, embedding_2)
# Out:
# tensor([[0.6003]])

# %%
import csv
# 입력 파일 경로1
# input_file = '/data/ngn_2024/movie_rec_llm/Keyword_Movie_Rec/dataset/meta_key_tk_223.csv'
input_file = './dataset/meta_key_tk_223.csv'
# 출력 파일 경로1
output_file = './dataset/title_genre.csv'

# %%
# title과 genres를 합치는 함수
def merge_title_and_genres(title, genres):
    return f"{title}, {', '.join(eval(genres))}"

# %%
# 다른 인코딩 방식 시도
try:
    with open(input_file, 'r', newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)

        # 새로운 파일에 데이터 쓰기
        with open(output_file, 'w', newline='', encoding='utf-8') as f_out:
            writer = csv.writer(f_out)

            # 헤더 쓰기
            writer.writerow(['idx', 'imdb_id', 'merged_data'])

            # 데이터 쓰기
            for idx, row in enumerate(reader):
                # title과 genres 합치기
                merged_data = merge_title_and_genres(row['title'], row['genres'])

                # idx, imdb_id, merged_data 쓰기
                writer.writerow([idx, row['imdb_id'], merged_data])

    print("데이터가 성공적으로 저장되었습니다. 새로운 파일:", output_file)

except UnicodeDecodeError:
    print("utf-8로 파일을 열 수 없습니다. 다른 인코딩 방식을 시도해주세요.")
# Out:
# 데이터가 성공적으로 저장되었습니다. 새로운 파일: ./dataset/title_genre.csv

# %%
# 입력 파일 경로2
input_file2 = './dataset/meta_key_tk_223.csv'
# 출력 파일 경로2
output_file2 = './dataset/tagline.csv'
# 출력 파일 경로3
output_file3 = './dataset/overview.csv'
# 출력 파일 경로4
output_file4 = './dataset/keywords.csv'

# %%
import csv
# keywords를 문자열로 반환하는 함수
def extract_keywords(keywords):
    # 문자열로 반환
    return eval(keywords)

try:
    with open(input_file2, 'r', newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)

        # 새 파일에 keywords 값 저장
        with open(output_file4, 'w', encoding='utf-8') as f_out:
            for idx, row in enumerate(reader):
                imdb_id = row['imdb_id']
                keywords = extract_keywords(row['keywords'])
                f_out.write(f"{idx},{imdb_id},\"{' '.join(keywords)}\"\n")

    print("keywords가 성공적으로 저장되었습니다. 새로운 파일:", output_file4)

except UnicodeDecodeError:
    print("utf-8로 파일을 열 수 없습니다. 다른 인코딩 방식을 시도해주세요.")
# Out:
# keywords가 성공적으로 저장되었습니다. 새로운 파일: ./dataset/keywords.csv

# %%
import csv
# keywords를 문자열로 반환하는 함수
def extract_tagline_tk(tagline_tk):
    # 문자열로 반환
    return eval(tagline_tk)

try:
    with open(input_file2, 'r', newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)

        # 새 파일에 keywords 값 저장
        with open(output_file2, 'w', encoding='utf-8') as f_out:
            for idx, row in enumerate(reader):
                imdb_id = row['imdb_id']
                tagline_tk = extract_tagline_tk(row['tagline_tk'])
                f_out.write(f"{idx},{imdb_id},\"{' '.join(tagline_tk)}\"\n")

    print("tagline_tk이 성공적으로 저장되었습니다. 새로운 파일:", output_file2)

except UnicodeDecodeError:
    print("utf-8로 파일을 열 수 없습니다. 다른 인코딩 방식을 시도해주세요.")
# Out:
# tagline_tk이 성공적으로 저장되었습니다. 새로운 파일: ./dataset/tagline.csv

# %%
import csv
# keywords를 문자열로 반환하는 함수
def extract_overview_tk(overview_tk):
    # 문자열로 반환
    return eval(overview_tk)

try:
    with open(input_file, 'r', newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)

        # 새 파일에 keywords 값 저장
        with open(output_file3, 'w', encoding='utf-8') as f_out:
            for idx, row in enumerate(reader):
                imdb_id = row['imdb_id']
                overview_tk = extract_overview_tk(row['overview_tk'])
                f_out.write(f"{idx},{imdb_id},\"{' '.join(overview_tk)}\"\n")

    print("overview_tk이 성공적으로 저장되었습니다. 새로운 파일:", output_file3)

except UnicodeDecodeError:
    print("utf-8로 파일을 열 수 없습니다. 다른 인코딩 방식을 시도해주세요.")
# Out:
# overview_tk이 성공적으로 저장되었습니다. 새로운 파일: ./dataset/overview.csv

# %%
# 사용자로부터 세 개의 단어를 입력받기
word1 = input("첫 번째 단어를 입력하세요: ")
word2 = input("두 번째 단어를 입력하세요: ")
word3 = input("세 번째 단어를 입력하세요: ")

# 입력받은 단어들을 ','로 연결하여 문장으로 반환
sentence = f"\"{word1}, {word2}, {word3}\""

# 결과 출력
print("입력한 단어들로 만든 문장:", sentence)
# Out:
# 입력한 단어들로 만든 문장: "musical, family, love"

# %%
import csv
# 입력 파일 경로
input_file = './dataset/keywords.csv'

# 딕셔너리 초기화
imdb_keywords_dict = {}

try:
    with open(input_file, 'r', newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        
        # 각 행 처리
        for row in reader:
            imdb_id = row[1]  # imdb_id는 두 번째 열에 위치
            keywords = row[2]  # keywords는 세 번째 열에 위치
            
            # 딕셔너리에 추가
            imdb_keywords_dict[imdb_id] = keywords

    # values 값을 리스트로 변환
    keywords_list = list(imdb_keywords_dict.values())

    print("딕셔너리 생성 완료:")
    print(imdb_keywords_dict)
    print("values를 리스트로 변환 완료:")
    print(keywords_list)



except UnicodeDecodeError:
    print("utf-8로 파일을 열 수 없습니다. 다른 인코딩 방식을 시도해주세요.")
# Out:
# 딕셔너리 생성 완료:
# {'tt0114709': 'jealousy toy boy friendship friends rivalry boy next door new toy toy comes to life', 'tt0113277': 'robbery detective bank obsession chase shooting thief honor murder suspense heist betrayal money gang cat and mouse criminal mastermind cult film ex-con heist movie one last job loner bank job neo-noir gun fight crime epic', 'tt0112641': 'poker drug abuse 1970s overdose illegal prostitution', 'tt0114369': 'self-fulfilling prophecy detective s.w.a.t. drug dealer evisceration lust and impulsiveness rage and hate pride and vanity immoderateness insomnia investigation pension police serial killer', 'tt0114814': 'law relatives theft criminal criminal mastermind hungarian sibling', 'tt0113247': 'paris neo-nazi skinhead robbery police brutality hip-hop
obia', 'individual scotland in love with enemy legend independence idealism revolt tyranny', 'vietnam veteran taxi obsession drug dealer night shift vigilante alienation misanthrope shot to death illegal prostitution loner', 'dialogue sunrise talking soulmates walking austria traveller danube bittersweet romantic vienna', 'android galaxy hermit death star lightsaber jedi rescue mission empire rebellion planet smuggler the force space opera galactic war stormtrooper totalitarianism', 'new york corruption assassin police brutality loss of family s.w.a.t. immigrant hitman training revenge murder loneliness neighbor tragic love cult film neo-noir complex relationship complex characters', 'transporter brothel drug dealer boxer massage stolen money crime boss dance contest junkyard kamikaze ambiguous ending briefcase redemption heirloom pulp fiction reference to al green theft brutality', 'prison corruption police brutality prison cell delinquent parole board escape from prison wrongful imprisonment framed for murder 1940s', 'vietnam veteran hippie mentally disabled running based on novel vietnam vietnam war friendship love family relationships bully mother son relationship military hugging shrimping wounded soldier flashback park bench amputee', 'loss of parents wild boar uncle shaman redemption king scar hyena meerkat', 'bomb prison father son relationship based on novel 1970s biography faith irish trial rebellion torture terrorism courtroom', 'exotic island dna paleontology tyrannosaurus rex triceratops brontosaurus electric fence island dinosaur amusement park theme park jurassic park', 'factory concentration camp hero holocaust world war ii nazis defense industry biography the holocaust', 'artificial intelligence bounty hunter dystopia genetics fugitive cyberpunk los angeles tech noir neo-noir futurista lluvia', 'magic musical cartoon princess love comedy animation monkey arab aftercreditsstinger genie animal sidekick', 'cyborg shotgun post-apocalyptic dystopia moral ambiguity mental institution violence fictional war morphing nuclear weapons shape shifter savior catch phrase', 'based on novel psychopath horror suspense serial killer psychological thriller cannibal fbi agent animal in cast credits cannibalism', 'cheating ransom salesclerk winter kidnapping auto unsociability police north dakota murder money car dealership woodchipper', 'robbery move monsoon difficult childhood dying and death misery priest teacher writer railroad unemployment help', 'usa president general cold war strategic air command nuclear missile war room bomber pilot nuclear weapons ex nazi doomsday device absurdism', 'london england alcohol sex based on novel drug addiction drug dealer nightclub junkie heroin cold turkey modern society hallucination friendship surrealism dark comedy stealing monologue cult film recovering drug addict illegal drugs drug deal drug rehabilitation drug culture antihero', 'italy love at first sight loss of father patriarch organized crime mafia lawyer italian american crime family rise to power mob boss 1940s', 'fan morning musical talkie partner movie in movie broadway audience chorus girl diction coach pearl necklace flapper', ...

# %%
import csv
# 입력 파일 경로
input_tg_file = './dataset/title_genre.csv'

# 딕셔너리 초기화
imdb_tg_dict = {}

try:
    with open(input_tg_file, 'r', newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        
        # 각 행 처리
        for row in reader:
            imdb_id = row[1]  # imdb_id는 두 번째 열에 위치
            title_genre = row[2]  # title_genre 세 번째 열에 위치
            
            # 딕셔너리에 추가
            imdb_tg_dict[imdb_id] = title_genre

    # values 값을 리스트로 변환
    tg_list = list(imdb_tg_dict.values())

    print("tg 딕셔너리 생성 완료:")
    print(imdb_tg_dict)
    print("values를 리스트로 변환 완료:")
    print(tg_list)



except UnicodeDecodeError:
    print("utf-8로 파일을 열 수 없습니다. 다른 인코딩 방식을 시도해주세요.")
# Out:
# tg 딕셔너리 생성 완료:
# {'imdb_id': 'merged_data', 'tt0114709': 'Toy Story, Animation, Comedy, Family', 'tt0113277': 'Heat, Action, Crime, Drama, Thriller', 'tt0112641': 'Casino, Drama, Crime', 'tt0114369': 'Se7en, Crime, Mystery, Thriller', 'tt0114814': 'The Usual Suspects, Drama, Crime, Thriller', 'tt0113247': 'La Haine, Drama', 'tt0112573': 'Braveheart, Action, Drama, History, War', 'tt0075314': 'Taxi Driver, Crime, Drama', 'tt0112471': 'Before Sunrise, Drama, Romance', 'tt0076759': 'Star Wars, Adventure, Action, Science Fiction', 'tt0110413': 'Leon: The Professional, Thriller, Crime, Drama', 'tt0110912': 'Pulp Fiction, Thriller, Crime', 'tt0111161': 'The Shawshank Redemption, Drama, Crime', 'tt0109830': 'Forrest Gump, Comedy, Drama, Romance', 'tt0110357': 'The Lion King, Family, Animation, Drama', 'tt0107207': 'In the Name of the Father, Drama', 'tt0107290': 'Jurassic Park, Adventure, Science Fiction', 'tt0108052': "Schindler's List, Drama, History, War", 'tt0083658': 'Blade Runner, Science Fiction, Drama, Thriller', 'tt0103639': 'Aladdin, Animation, Family, Comedy, Adventure, Fantasy, Romance', 'tt0103064': 'Terminator 2: Judgment Day, Action, Thriller, Science Fiction', 'tt0102926': 'The Silence of the Lambs, Crime, Drama, Thriller', 'tt0116282': 'Fargo, Crime, Drama, Thriller', 'tt0048473': 'Pather Panchali, Drama', 'tt0057012': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb, Drama, Comedy, War', 'tt0117951': 'Trainspotting, Drama, Crime', 'tt0068646': 'The Godfather, Drama, Crime', 'tt0045152': "Singin' in the Rain, Comedy, Music, Romance", 'tt0052357': 'Vertigo, Mystery, Romance, Thriller', 'tt0047396': 'Rear Window, Drama, Mystery, Thriller', 'tt0025316': 'It Happened One Night, Comedy, Romance', 'tt0053125': 'North by Northwest, Mystery, Thriller', 'tt0053604': 'The Apartment, Comedy, Drama, Romance', 'tt0053291': 'Some Like It Hot, Comedy, Romance', 'tt0034583': 'Casablanca, Drama, Romance', 'tt0032138': 'The Wizard of Oz, Adventure, Family, Fantasy', 'tt0031381': 'Gone with the Wind, Drama, Romance, War', 'tt0043014': 'Sunset Boulevard, Drama', 'tt0033467': 'Citizen Kane, Mystery, Drama', 'tt0062622': '2001: A Space Odyssey, Science Fiction, Mystery, Adventure', 'tt0042192': 'All About Eve, Drama', 'tt0032976': 'Rebecca, Drama, Mystery', 'tt0035446': 'To Be or Not to Be, Comedy, War', 'tt0038650': "It's a Wonderful Life, Drama, Family, Fantasy", 'tt0031679': 'Mr. Smith Goes to Washington, Comedy, Drama', 'tt0059742': 'The Sound of Music, Drama, Family, Music, Romance', 'tt0095016': 'Die Hard, Action, Thriller', 'tt0079470': 'Life of Brian, Comedy', 'tt0046912': 'Dial M for Murder, Crime, Mystery, Thriller', 'tt0105236': 'Reservoir Dogs, Crime, Thriller', 'tt0091763': 'Platoon, Drama, War, Action', 'tt0071853': 'Monty Python and the Holy Grail, Adventure, Comedy, Fantasy', 'tt0095765': 'Cinema Paradiso, Drama, Romance', 'tt0050825': 'Paths of Glory, Drama, War', 'tt0073486': "One Flew Over the Cuckoo's Nest, Drama", 'tt0080684': 'The Empire Strikes Back, Adventure, Action, Science Fiction', 'tt0082971': 'Raiders of the Lost Ark, Adventure, Action', 'tt0090605': 'Aliens, Horror, Action, Thriller, Science Fiction', 'tt0060196': 'The Good, the Bad and the Ugly, Western', 'tt0050083': '12 Angry Men, Drama', 'tt0056172': 'Lawrence of Arabia, Adventure, Drama, History, War', 'tt0066921': 'A Clockwork Orange, Science Fiction, Drama', 'tt0056592': 'To Kill a Mockingbird, Crime, Drama', 'tt0078788': 'Apocalypse Now, Drama, War', 'tt0064116': 'Once Upon a Time in the West, Western', 'tt0086190': 'Return of the Jedi, Adventure, Action, Science Fiction', 'tt0041959': 'The Third Man, Thriller, Mystery', 'tt0099685': 'GoodFellas, Drama, Crime', 'tt0078748': 'Alien, Horror, Action, Thriller, Science Fiction', 'tt0054215': 'Psycho, Drama, Horror, Thriller', 'tt0071562': 'The Godfather: Part II, Drama, Crime', 'tt0093058': 'Full Metal Jacket, Drama, War', 'tt0086879': 'Amadeus, Drama, History, Music', 'tt0087843': 'Once Upon a Time  ...
# values를 리스트로 변환 완료:
# ['merged_data', 'Toy Story, Animation, Comedy, Family', 'Heat, Action, Crime, Drama, Thriller', 'Casino, Drama, Crime', 'Se7en, Crime, Mystery, Thriller', 'The Usual Suspects, Drama, Crime, Thriller', 'La Haine, Drama', 'Braveheart, Action, Drama, History, War', 'Taxi Driver, Crime, Drama', 'Before Sunrise, Drama, Romance', 'Star Wars, Adventure, Action, Science Fiction', 'Leon: The Professional, Thriller, Crime, Drama', 'Pulp Fiction, Thriller, Crime', 'The Shawshank Redemption, Drama, Crime', 'Forrest Gump, Comedy, Drama, Romance', 'The Lion King, Family, Animation, Drama', 'In the Name of the Father, Drama', 'Jurassic Park, Adventure, Science Fiction', "Schindler's List, Drama, History, War", 'Blade Runner, Science Fiction, Drama, Thriller', 'Aladdin, Animation, Family, Comedy, Adventure, Fantasy, Romance', 'Terminator 2: Judgment Day, Action, Thriller, Science Fiction', 'The Silence of the Lambs, Crime, Drama, Thriller', 'Fargo, Crime, Drama, Thriller', 'Pather Panchali, Drama', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb, Drama, Comedy, War', 'Trainspotting, Drama, Crime', 'The Godfather, Drama, Crime', "Singin' in the Rain, Comedy, Music, Romance", 'Vertigo, Mystery, Romance, Thriller', 'Rear Window, Drama, Mystery, Thriller', 'It Happened One Night, Comedy, Romance', 'North by Northwest, Mystery, Thriller', 'The Apartment, Comedy, Drama, Romance', 'Some Like It Hot, Comedy, Romance', 'Casablanca, Drama, Romance', 'The Wizard of Oz, Adventure, Family, Fantasy', 'Gone with the Wind, Drama, Romance, War', 'Sunset Boulevard, Drama', 'Citizen Kane, Mystery, Drama', '2001: A Space Odyssey, Science Fiction, Mystery, Adventure', 'All About Eve, Drama', 'Rebecca, Drama, Mystery', 'To Be or Not to Be, Comedy, War', "It's a Wonderful Life, Drama, Family, Fantasy", 'Mr. Smith Goes to Washington, Comedy, Drama', 'The Sound of Music, Drama, Family, Music, Romance', 'Die Hard, Action, Thriller', 'Life of Brian, Comedy', 'Dial M for Murder, Crime, Mystery, Thriller', 'Reservoir Dogs, Crime, Thriller', 'Platoon, Drama, War, Action', 'Monty Python and the Holy Grail, Adventure, Comedy, Fantasy', 'Cinema Paradiso, Drama, Romance', 'Paths of Glory, Drama, War', "One Flew Over the Cuckoo's Nest, Drama", 'The Empire Strikes Back, Adventure, Action, Science Fiction', 'Raiders of the Lost Ark, Adventure, Action', 'Aliens, Horror, Action, Thriller, Science Fiction', 'The Good, the Bad and the Ugly, Western', '12 Angry Men, Drama', 'Lawrence of Arabia, Adventure, Drama, History, War', 'A Clockwork Orange, Science Fiction, Drama', 'To Kill a Mockingbird, Crime, Drama', 'Apocalypse Now, Drama, War', 'Once Upon a Time in the West, Western', 'Return of the Jedi, Adventure, Action, Science Fiction', 'The Third Man, Thriller, Mystery', 'GoodFellas, Drama, Crime', 'Alien, Horror, Action, Thriller, Science Fiction', 'Psycho, Drama, Horror, Thriller', 'The Godfather: Part II, Drama, Crime', 'Full Metal Jacket, Drama, War', 'Amadeus, Drama, History, Music', 'Once Upon a Time in America, Drama, Crime', 'Raging Bull, Drama', 'Das Boot, Action, Drama, History, War, Adventure', 'The Sting, Comedy, Crime, Drama', 'The Seventh Seal, Fantasy, Drama', 'The Terminator, Action, Thriller, Science Fiction', 'Dead Poets Society, Drama', 'The Bridge on the River Kwai, Drama, History, War', 'Chinatown, Crime, Drama, Mystery, Thriller', 'The Treasure of the Sierra Madre, Action, Adventure, Drama, Western', 'The Shining, Horror, Thriller', 'Stand by Me, Crime, Drama', 'M, Drama, Action, Thriller, Crime', 'The Great Escape, Adventure, Drama, History, Thriller, War', 'The Deer Hunter, Drama, War', 'Groundhog Day, Romance, Fantasy, Drama, Comedy', 'Unforgiven, Western', 'Back to the Future, Adventure, Comedy, Science Fiction, Family', 'Cool Hand Luke, Crime, Drama', 'The Great Dictator, Comedy', 'Ben-Hur, Action, Adventure, Drama, History', 'Indiana Jones and the Last Crusade, Adventure, Action', 'Gandhi, Drama, History', 'Jaws, Horror, Thriller, Ad ...

# %%
import csv
# 입력 파일 경로
input_overview_file = './dataset/overview.csv'

# 딕셔너리 초기화
imdb_overview_dict = {}

try:
    with open(input_overview_file, 'r', newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        
        # 각 행 처리
        for row in reader:
            imdb_id = row[1]  # imdb_id는 두 번째 열에 위치
            overview = row[2]  # overview 세 번째 열에 위치
            
            # 딕셔너리에 추가
            imdb_overview_dict[imdb_id] = overview

    # values 값을 리스트로 변환
    overview_list = list(imdb_overview_dict.values())

    print("overview 딕셔너리 생성 완료:")
    print(imdb_overview_dict)
    print("values를 리스트로 변환 완료:")
    print(overview_list)



except UnicodeDecodeError:
    print("utf-8로 파일을 열 수 없습니다. 다른 인코딩 방식을 시도해주세요.")
# Out:
# overview 딕셔너리 생성 완료:
# ['led woody andy toys live happily room andy birthday brings buzz lightyear onto scene afraid losing place andy heart woody plots buzz circumstances separate buzz woody owner duo eventually learns put aside differences', 'obsessive master thief neil mccauley leads top-notch crew various insane heists throughout los angeles mentally unstable detective vincent hanna pursues without rest man recognizes respects ability dedication even though aware cat-and-mouse game may end violence', 'life gambling paradise las vegas dark mafia underbelly', 'two homicide detectives desperate hunt serial killer whose crimes based seven deadly sins dark haunting film takes viewers tortured remains one victim next seasoned det sommerset researches sin effort get inside killer mind novice partner mills scoffs efforts unravel case', 'held l.a. interrogation room verbal kint attempts convince feds mythic crime lord keyser soze exists also responsible drawing four partners multi-million dollar heist ended explosion san pedro harbor leaving survivors verbal lures interrogators incredible story crime lord almost supernatural prowess', 'aimlessly whiling away days concrete environs dead-end suburbia vinz hubert said -- jew african arab -- give human faces france immigrant populations bristling resentment social marginalization slowly simmering reaches climactic boiling point la haine means hate', 'enraged slaughter murron new bride childhood love scottish warrior william wallace slays platoon local english lord soldiers leads village revolt eventually entire country rise english rule', 'mentally unstable vietnam war veteran works night-time taxi driver new york city perceived decadence sleaze feeds urge violent action attempting save preadolescent prostitute process', 'dialogue marathon film fairytale love story american boy french girl day night together vienna two hearts collide', 'princess leia captured held hostage evil imperial forces effort take galactic empire venturesome luke skywalker dashing captain han solo team together loveable robot duo r2-d2 c-3po rescue beautiful princess restore peace justice empire', 'leon top hit man new york earned rep effective cleaner next-door neighbors wiped loose-cannon dea agent becomes unwilling custodian 12-year-old mathilda long mathilda thoughts turn revenge considers following leon footsteps', 'burger-loving hit man philosophical partner drug-addled gangster moll washed-up boxer converge sprawling comedic crime caper adventures unfurl three stories ingeniously trip back forth time', 'framed 1940s double murder wife lover upstanding banker andy dufresne begins new life shawshank prison puts accounting skills work amoral warden long stretch prison dufresne comes admired inmates -- including older prisoner named red -- integrity unquenchable sense hope', "man low iq accomplished great things life present significant historic events - case far exceeding anyone imagined could yet despite things attained one true love eludes 'forrest gump ' story man rose challenges proved determination courage love important ability", "young lion cub named simba ca n't wait king uncle craves title stop nothing get", 'small time thief belfast gerry conlon falsely implicated ira bombing pub kills several people london four friends coerced british police confessing guilt gerry father relatives london also implicated crime spends fifteen years prison father trying prove innocence', 'wealthy entrepreneur secretly creates theme park featuring living dinosaurs drawn prehistoric dna opening day invites team experts two eager grandchildren experience park help calm anxious investors however park anything amusing security systems go off-line dinosaurs escape', 'true story businessman oskar schindler saved thousand jewish lives nazis worked slaves factory world war ii', 'smog-choked dystopian los angeles 2019 blade runner rick deckard called retirement terminate quartet replicants escaped earth seeking creator way extend short life spans',  ...

# %%
import csv
# 입력 파일 경로
input_overview_file = './dataset/tagline.csv'

# 딕셔너리 초기화
imdb_overview_dict = {}

try:
    with open(input_overview_file, 'r', newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        
        # 각 행 처리
        for row in reader:
            imdb_id = row[1]  # imdb_id는 두 번째 열에 위치
            overview = row[2]  # overview 세 번째 열에 위치
            
            # 딕셔너리에 추가
            imdb_overview_dict[imdb_id] = overview

    # values 값을 리스트로 변환
    overview_list = list(imdb_overview_dict.values())

    print("overview 딕셔너리 생성 완료:")
    print(imdb_overview_dict)
    print("values를 리스트로 변환 완료:")
    print(overview_list)



except UnicodeDecodeError:
    print("utf-8로 파일을 열 수 없습니다. 다른 인코딩 방식을 시도해주세요.")
# Out:
# overview 딕셔너리 생성 완료:
# {'tt0114709': '', 'tt0113277': 'los angeles crime saga', 'tt0112641': 'one stays top forever', 'tt0114369': 'seven deadly sins seven ways die', 'tt0114814': 'five criminals one line coincidence', 'tt0113247': 'three young friends one last chance', 'tt0112573': 'every man dies every man truly lives', 'tt0075314': 'every street every city nobody dreams somebody', 'tt0112471': 'greatest romance life last one night', 'tt0076759': 'long time ago galaxy far far away', 'tt0110413': 'want job done well hire professional', 'tt0110912': 'character mean character', 'tt0111161': 'fear hold prisoner hope set free', 'tt0109830': "world never 've seen eyes forrest gump", 'tt0110357': 'life greatest adventure finding place circle life', 'tt0107207': 'falsely accused wrongly imprisoned fought justice clear father name', 'tt0107290': 'adventure 65 million years making', 'tt0108052': 'whoever saves one life saves world entire', 'tt0083658': 'man made match problem', 'tt0103639': 'wish granted', 'tt0103064': 'nothing personal', 'tt0102926': 'enter mind killer must challenge mind madman', 'tt0116282': 'lot happen middle nowhere', 'tt0048473': '', 'tt0057012': 'hot-line suspense comedy', 'tt0117951': 'choose life', 'tt0068646': 'offer ca refuse', 'tt0045152': 'glorious feeling', 'tt0052357': 'alfred hitchcock engulfs whirlpool terror tension', 'tt0047396': 'takes one witness spoil perfect crime', 'tt0025316': 'together first time', 'tt0053125': "deadly game 'tag cary grant 'it", 'tt0053604': 'movie-wise never anything like - laugh-wise love-wise otherwise-wise', 'tt0053291': 'movie hot words', 'tt0034583': 'date fate casablanca', 'tt0032138': "'re see wizard wonderful wizard oz", 'tt0031381': 'greatest romance time', 'tt0043014': 'hollywood story', 'tt0033467': 'terrific', 'tt0062622': 'epic drama adventure exploration', 'tt0042192': 'women men', 'tt0032976': 'shadow woman darkened love', 'tt0035446': '', 'tt0038650': 'wonderful laugh wonderful love', 'tt0031679': 'romance drama laughter heartbreak created heart soil america', 'tt0059742': 'happiest sound world', 'tt0095016': '40 stories twelve terrorists one cop', 'tt0079470': 'messiah naughty boy', 'tt0046912': 'woman answers hang dear life', 'tt0105236': 'every dog day', 'tt0091763': 'first casualty war innocence', 'tt0071853': 'last another film completely different films quite one', 'tt0095765': 'celebration youth friendship everlasting magic movies', 'tt0050825': 'explodes no-man land picture ever dared cross', 'tt0073486': 'crazy make', 'tt0080684': 'adventure continues', 'tt0082971': 'indiana jones - new hero creators jaws star wars', 'tt0090605': 'time war', 'tt0060196': 'three men civil war hell practice', 'tt0050083': 'life hands death minds', 'tt0056172': '', 'tt0066921': 'adventures young man whose principal interests rape ultra-violence beethoven', 'tt0056592': '', 'tt0078788': 'end', 'tt0064116': 'three men life one take one love one kill', 'tt0086190': 'empire falls', 'tt0041959': 'hunted men sought women', 'tt0099685': 'three decades life mafia', 'tt0078748': 'space one hear scream', 'tt0054215': 'master suspense moves cameras icy blackness unexplored', 'tt0071562': 'feel wipe everybody tom enemies', 'tt0093058': 'vietnam kill make care', 'tt0086879': "everything 've heard true", 'tt0087843': 'crime passion lust power - sergio leone explosive saga gangland america', 'tt0081398': '', 'tt0082096': 'hunters become hunted', 'tt0070735': 'takes little confidence', 'tt0050976': '', 'tt0088247': 'future hands', 'tt0097165': 'inspiration made lives extraordinary', 'tt0050212': 'spans whole new world entertainment', 'tt0071315': 'get tough get tender get close maybe even get close truth', 'tt0040897': 'nearer get treasure farther get law', 'tt0081505': 'masterpiece modern horror', 'tt0092005': 'last real taste innocence first real taste life everyone time memories made', 'tt0022100': '', 'tt0057115': "put fence front men 'll climb", 'tt0077416': 'one important powerful films time', 'tt01070 ...
# values를 리스트로 변환 완료:
# ['', 'los angeles crime saga', 'one stays top forever', 'seven deadly sins seven ways die', 'five criminals one line coincidence', 'three young friends one last chance', 'every man dies every man truly lives', 'every street every city nobody dreams somebody', 'greatest romance life last one night', 'long time ago galaxy far far away', 'want job done well hire professional', 'character mean character', 'fear hold prisoner hope set free', "world never 've seen eyes forrest gump", 'life greatest adventure finding place circle life', 'falsely accused wrongly imprisoned fought justice clear father name', 'adventure 65 million years making', 'whoever saves one life saves world entire', 'man made match problem', 'wish granted', 'nothing personal', 'enter mind killer must challenge mind madman', 'lot happen middle nowhere', '', 'hot-line suspense comedy', 'choose life', 'offer ca refuse', 'glorious feeling', 'alfred hitchcock engulfs whirlpool terror tension', 'takes one witness spoil perfect crime', 'together first time', "deadly game 'tag cary grant 'it", 'movie-wise never anything like - laugh-wise love-wise otherwise-wise', 'movie hot words', 'date fate casablanca', "'re see wizard wonderful wizard oz", 'greatest romance time', 'hollywood story', 'terrific', 'epic drama adventure exploration', 'women men', 'shadow woman darkened love', '', 'wonderful laugh wonderful love', 'romance drama laughter heartbreak created heart soil america', 'happiest sound world', '40 stories twelve terrorists one cop', 'messiah naughty boy', 'woman answers hang dear life', 'every dog day', 'first casualty war innocence', 'last another film completely different films quite one', 'celebration youth friendship everlasting magic movies', 'explodes no-man land picture ever dared cross', 'crazy make', 'adventure continues', 'indiana jones - new hero creators jaws star wars', 'time war', 'three men civil war hell practice', 'life hands death minds', '', 'adventures young man whose principal interests rape ultra-violence beethoven', '', 'end', 'three men life one take one love one kill', 'empire falls', 'hunted men sought women', 'three decades life mafia', 'space one hear scream', 'master suspense moves cameras icy blackness unexplored', 'feel wipe everybody tom enemies', 'vietnam kill make care', "everything 've heard true", 'crime passion lust power - sergio leone explosive saga gangland america', '', 'hunters become hunted', 'takes little confidence', '', 'future hands', 'inspiration made lives extraordinary', 'spans whole new world entertainment', 'get tough get tender get close maybe even get close truth', 'nearer get treasure farther get law', 'masterpiece modern horror', 'last real taste innocence first real taste life everyone time memories made', '', "put fence front men 'll climb", 'one important powerful films time', 'worst day life', 'legends never forgotten wrongs never forgiven', 'kid ever get trouble born', "'ve got failure communicate", '- whole world laughs', 'entertainment experience lifetime', 'man hat back time bringing dad', 'triumph changed world forever', 'go water', 'everything suspect everyone sale nothing seems', 'air unaware', 'people never believe someone believes', 'times like call big lebowski', 'little secret biggest adventure', 'three wonderful loves best picture year', 'man lived jungle law docks', 'whole life million-to-one shot', 'something almost beyond comprehension happening girl street house man sent last resort man exorcist', 'understanding hands brain unless heart acts mediator', 'mighty warriors became seven national heroes small town', 'mission man', 'man warmest place hide', 'animal human man', 'unforgettable fable proves love family imagination conquer', 'legacies must end', 'disgrace criminals everywhere', 'welcome real world', 'long last redmond barry became gentleman - tragedy', 'angel faces hell-bent violence', 'came outer space', 'every gift blessing', 'look closer', 'mischief mayhem soap', 'buster drives gen ...

# %%
### keywords
from sentence_transformers import SentenceTransformer, util
# sentences = ["I'm happy", "I'm full of happiness"]

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

#Compute embedding for both lists
embedding_input= model.encode(sentence, convert_to_tensor=True)

key_cosim_list=[]
for i in range(len(keywords_list)):
    embedding_compare = model.encode(keywords_list[i], convert_to_tensor=True)
    sentence_sim=util.pytorch_cos_sim(embedding_input, embedding_compare)
    key_cosim_list.append(sentence_sim)

# print(cos_sim_list)

# %%
# 상위 10개의 인덱스와 sentence_sim 값을 출력
key_top_similarities = sorted(enumerate(key_cosim_list), key=lambda x: x[1], reverse=True)[:10]

for idx, similarity in key_top_similarities:
    print(f"Index: {idx}, Similarity: {similarity}", key_cosim_list[idx], keywords_list[idx])
# Out:
# Index: 186, Similarity: tensor([[0.3910]]) tensor([[0.3910]]) romantic comedy
# Index: 35, Similarity: tensor([[0.3658]]) tensor([[0.3658]]) witch adolescence based on novel secret identity clock dream lion tornado scarecrow musical crow music kansas classic imaginary land cowardliness sepia color
# Index: 65, Similarity: tensor([[0.3411]]) tensor([[0.3411]]) rebel brother sister relationship emperor space battle matter of life and death spaceship death star jabba the hutt ewoks jedi space opera
# Index: 27, Similarity: tensor([[0.3337]]) tensor([[0.3337]]) fan morning musical talkie partner movie in movie broadway audience chorus girl diction coach pearl necklace flapper
# Index: 72, Similarity: tensor([[0.3117]]) tensor([[0.3117]]) italy composer opera talent musician marriage crisis god murder vienna austria envy 18th century
# Index: 61, Similarity: tensor([[0.3068]]) tensor([[0.3068]]) prison street gang rape adolescence sexuality beethoven parent child relationship social worker living together society dystopia controversy controversial violence futuristic society
# Index: 70, Similarity: tensor([[0.2989]]) tensor([[0.2989]]) italo-american cuba vororte melancholy praise revenge mafia lawyer blood corrupt politician bloody body of child man punches woman
# Index: 140, Similarity: tensor([[0.2890]]) tensor([[0.2890]]) paris love triangle ghost train sex-shop shyness montmartre daughter garden gnome journey round the world photography
# Index: 13, Similarity: tensor([[0.2880]]) tensor([[0.2880]]) vietnam veteran hippie mentally disabled running based on novel vietnam vietnam war friendship love family relationships bully mother son relationship military hugging shrimping wounded soldier flashback park bench amputee
# Index: 149, Similarity: tensor([[0.2862]]) tensor([[0.2862]]) individual resistance radio station war crimes loss of family child murderer hunger world war ii prisoners of war homeland deportation hiding place ghetto riot jew persecution liberation warsaw ghetto polish resistance nazis biography classical music panzer pianist

# %%
### title_genre
from sentence_transformers import SentenceTransformer, util
# sentences = ["I'm happy", "I'm full of happiness"]

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Index: 181, Similarity: tensor([[0.4656]]) tensor([[0.4656]]) My Father and My Son, Comedy, Drama
# Index: 218, Similarity: tensor([[0.4546]]) tensor([[0.4546]]) Inside Out, Drama, Comedy, Animation, Family
# Index: 20, Similarity: tensor([[0.4423]]) tensor([[0.4423]]) Aladdin, Animation, Family, Comedy, Adventure, Fantasy, Romance

# %%
### overview
from sentence_transformers import SentenceTransformer, util
# sentences = ["I'm happy", "I'm full of happiness"]

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

#Compute embedding for both lists
embedding_input= model.encode(sentence, convert_to_tensor=True)

overview_cosim_list=[]
for i in range(len(overview_list)):
    embedding_compare = model.encode(overview_list[i], convert_to_tensor=True)
    sentence_sim=util.pytorch_cos_sim(embedding_input, embedding_compare)
    overview_cosim_list.append(sentence_sim)

print(overview_cosim_list)
# Out:
# [tensor([[0.0996]]), tensor([[0.1332]]), tensor([[-0.0028]]), tensor([[0.0478]]), tensor([[0.1044]]), tensor([[0.1290]]), tensor([[0.1306]]), tensor([[0.1778]]), tensor([[0.3272]]), tensor([[0.0016]]), tensor([[0.0358]]), tensor([[0.0871]]), tensor([[0.1574]]), tensor([[0.1696]]), tensor([[0.2352]]), tensor([[0.0471]]), tensor([[0.1128]]), tensor([[0.0927]]), tensor([[0.0192]]), tensor([[0.1352]]), tensor([[0.1015]]), tensor([[0.0086]]), tensor([[0.1334]]), tensor([[0.0996]]), tensor([[0.2238]]), tensor([[0.1760]]), tensor([[0.0596]]), tensor([[0.1320]]), tensor([[0.1136]]), tensor([[0.0876]]), tensor([[0.2042]]), tensor([[0.1036]]), tensor([[0.3145]]), tensor([[0.2430]]), tensor([[0.1767]]), tensor([[0.1963]]), tensor([[0.3544]]), tensor([[0.1994]]), tensor([[0.1060]]), tensor([[0.2602]]), tensor([[0.1120]]), tensor([[0.1963]]), tensor([[0.0996]]), tensor([[0.2628]]), tensor([[0.3870]]), tensor([[0.3153]]), tensor([[0.0228]]), tensor([[0.2932]]), tensor([[0.1164]]), tensor([[0.0996]]), tensor([[-0.0136]]), tensor([[0.1440]]), tensor([[0.3073]]), tensor([[-0.0116]]), tensor([[0.1416]]), tensor([[0.1781]]), tensor([[0.1276]]), tensor([[0.1544]]), tensor([[0.0418]]), tensor([[0.1515]]), tensor([[0.0996]]), tensor([[0.3175]]), tensor([[0.0996]]), tensor([[0.1125]]), tensor([[0.2564]]), tensor([[0.1249]]), tensor([[0.0363]]), tensor([[0.1840]]), tensor([[0.2090]]), tensor([[0.0112]]), tensor([[0.0447]]), tensor([[0.0601]]), tensor([[0.1231]]), tensor([[0.2238]]), tensor([[0.0996]]), tensor([[-0.0011]]), tensor([[-0.0297]]), tensor([[0.0996]]), tensor([[0.0987]]), tensor([[0.1698]]), tensor([[0.2184]]), tensor([[0.0674]]), tensor([[-0.0109]]), tensor([[0.3082]]), tensor([[0.2436]]), tensor([[0.0996]]), tensor([[-0.0031]]), tensor([[0.1810]]), tensor([[0.1266]]), tensor([[0.1078]]), tensor([
# Index: 111, Similarity: tensor([[0.4466]]) tensor([[0.4466]]) unforgettable fable proves love family imagination conquer
# Index: 202, Similarity: tensor([[0.4309]]) tensor([[0.4309]]) fight family
# Index: 44, Similarity: tensor([[0.3870]]) tensor([[0.3870]]) romance drama laughter heartbreak created heart soil america
# Index: 125, Similarity: tensor([[0.3555]]) tensor([[0.3555]]) true blind love
# Index: 36, Similarity: tensor([[0.3544]]) tensor([[0.3544]]) greatest romance time
# Index: 169, Similarity: tensor([[0.3500]]) tensor([[0.3500]]) beyond silence past beyond dreams feeling beyond hope memory beyond journey love
# Index: 8, Similarity: tensor([[0.3272]]) tensor([[0.3272]]) greatest romance life last one night
# Index: 61, Similarity: tensor([[0.3175]]) tensor([[0.3175]]) adventures young man whose principal interests rape ultra-violence beethoven
# Index: 45, Similarity: tensor([[0.3153]]) tensor([[0.3153]]) happiest sound world

# %%
sim_list = [tg_cosim_list, key_cosim_list, overview_cosim_list]

sum_sim_list = [sum(lst) for lst in zip(*sim_list)]

sorted_sums = sorted(enumerate(sum_sim_list), key=lambda x: x[1], reverse=True)

# %%
print(len(sorted_sums))
# 결과 출력

print("각 리스트의 원소를 더한 값과 해당 인덱스의 내림차순 정렬:")
for idx, value in sorted_sums:
    print(f"Index: {idx}, Sum: {value}, Title: {tg_list[idx]}")
# Out:
# 223
# 각 리스트의 원소를 더한 값과 해당 인덱스의 내림차순 정렬:
# Index: 218, Sum: tensor([[1.0218]]), Title: Inside Out, Drama, Comedy, Animation, Family
# Index: 149, Sum: tensor([[0.9882]]), Title: Catch Me If You Can, Drama, Crime
# Index: 44, Sum: tensor([[0.9739]]), Title: It's a Wonderful Life, Drama, Family, Fantasy
# Index: 35, Sum: tensor([[0.9482]]), Title: Casablanca, Drama, Romance
# Index: 36, Sum: tensor([[0.9042]]), Title: The Wizard of Oz, Adventure, Family, Fantasy
# Index: 28, Sum: tensor([[0.8801]]), Title: Singin' in the Rain, Comedy, Music, Romance
# Index: 125, Sum: tensor([[0.8790]]), Title: The Green Mile, Fantasy, Drama, Crime
# Index: 61, Sum: tensor([[0.8583]]), Title: Lawrence of Arabia, Adventure, Drama, History, War
# Index: 192, Sum: tensor([[0.8569]]), Title: Mary and Max, Animation, Comedy, Drama
# Index: 52, Sum: tensor([[0.8565]]), Title: Monty Python and the Holy Grail, Adventure, Comedy, Fantasy
# Index: 181, Sum: tensor([[0.8560]]), Title: My Father and My Son, Comedy, Drama
# Index: 33, Sum: tensor([[0.8476]]), Title: The Apartment, Comedy, Drama, Romance
# Index: 126, Sum: tensor([[0.8461]]), Title: City Lights, Comedy, Drama, Romance
# Index: 111, Sum: tensor([[0.8266]]), Title: The Elephant Man, Drama, History
# Index: 137, Sum: tensor([[0.8228]]), Title: Memento, Mystery, Thriller
# Index: 73, Sum: tensor([[0.8120]]), Title: Amadeus, Drama, History, Music
# Index: 27, Sum: tensor([[0.8105]]), Title: The Godfather, Drama, Crime
# Index: 140, Sum: tensor([[0.8097]]), Title: Monsters, Inc., Animation, Comedy, Family
# Index: 8, Sum: tensor([[0.7951]]), Title: Taxi Driver, Crime, Drama
# Index: 72, Sum: tensor([[0.7765]]), Title: Full Metal Jacket, Drama, War
# Index: 184, Sum: tensor([[0.7728]]), Title: There Will Be Blood, Drama
# Index: 132, Sum: tensor([[0.7725]]), Title: Gladiator, Action, Drama, Adventure
# Index: 46, Sum: tensor([[0.7537]]), Title: The Sound of Music, Drama, Family, Music, Romance
# Index: 32, Sum: tensor([[0.7441]]), Title: North by Northwest, Mystery, Thriller
# Index: 186, Sum: tensor([[0.7430]]), Title: The Dark Knight, Drama, Action, Crime, Thriller
# Index: 102, Sum: tensor([[0.7335]]), Title: Children of Heaven, Drama, Comedy, Family
# Index: 47, Sum: tensor([[0.7328]]), Title: Die Hard, Action, Thriller
# Index: 34, Sum: tensor([[0.7326]]), Title: Some Like It Hot, Comedy, Romance
# Index: 150, Sum: tensor([[0.7286]]), Title: The Pianist, Drama, War
# Index: 45, Sum: tensor([[0.7272]]), Title: Mr. Smith Goes to Washington, Comedy, Drama
# Index: 197, Sum: tensor([[0.7256]]), Title: Toy Story 3, Animation, Family, Comedy
# Index: 101, Sum: tensor([[0.7243]]), Title: The Big Lebowski, Comedy, Crime
# Index: 1, Sum: tensor([[0.7193]]), Title: Toy Story, Animation, Comedy, Family
# Index: 13, Sum: tensor([[0.7136]]), Title: The Shawshank Redemption, Drama, Crime
# Index: 14, Sum: tensor([[0.7118]]), Title: Forrest Gump, Comedy, Drama, Romance
# Index: 84, Sum: tensor([[0.7036]]), Title: The Shining, Horror, Thriller
# Index: 153, Sum: tensor([[0.6949]]), Title: Pirates of the Caribbean: The Curse of the Black Pearl, Adventure, Fantasy, Action
# Index: 127, Sum: tensor([[0.6943]]), Title: The Kid, Comedy, Drama
# Index: 138, Sum: tensor([[0.6898]]), Title: Amores perros, Drama, Thriller
# Index: 65, Sum: tensor([[0.6859]]), Title: Once Upon a Time in the West, Western
# Index: 116, Sum: tensor([[0.6792]]), Title: Barry Lyndon, Drama, Romance, War
# Index: 202, Sum: tensor([[0.6766]]), Title: A Separation, Drama
# Index: 15, Sum: tensor([[0.6723]]), Title: The Lion King, Family, Animation, Drama
# Index: 43, Sum: tensor([[0.6700]]), Title: To Be or Not to Be, Comedy, War
# Index: 190, Sum: tensor([[0.6692]]), Title: Up, Animation, Comedy, Family, Adventure
# Index: 64, Sum: tensor([[0.6654]]), Title: Apocalypse Now, Drama, War
# Index: 37, Sum: tensor([[0.6616]]), Title: Gone with the Wind, Drama, Romance, War
# Index: 25, Sum: tensor([[0.6611]]), Title: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb, Drama, Comedy, War
# Index: 183, Sum: tensor([[0.6551]]), Title: No Country for Old Men, Crime, Drama, Thriller
# Index: 83, Sum: tensor([[0.6541]]), Title: The Treasure of the Sierra Madre, Action, Adventure, Drama, Western
# Index: 120, Sum: tensor([[0.6492]]), Title: American Beauty, Drama
# Index: 51, Sum: tensor([[0.6432]]), Title: Platoon, Drama, War, Action
# Index: 112, Sum: tensor([[0.6384]]), Title: Life Is Beautiful, Comedy, Drama
# Index: 219, Sum: tensor([[0.6375]]), Title: Room, Drama, Thriller
# Index: 212, Sum: tensor([[0.6295]]), Title: The Grand Budapest Hotel, Comedy, Drama
# Index: 68, Sum: tensor([[0.6252]]), Title: GoodFellas, Drama, Crime
# Index: 70, Sum: tensor([[0.6244]]), Title: Psycho, Drama, Horror, Thriller
# Index: 48, Sum: tensor([[0.6214]]), Title: Life of Brian, Comedy
# Index: 200, Sum: tensor([[0.6202]]), Title: Harry Potter and the Deathly Hallows: Part 2, Family, Fantasy, Adventure
# Index: 169, Sum: tensor([[0.6197]]), Title: Oldboy, Drama, Thriller, Mystery, Action
# Index: 42, Sum: tensor([[0.6190]]), Title: Rebecca, Drama, Mystery
# Index: 217, Sum: tensor([[0.6163]]), Title: Mad Max: Fury Road, Action, Adventure, Science Fiction, Thriller
# Index: 118, Sum: tensor([[0.6151]]), Title: The Iron Giant, Adventure, Animation, Family, Fantasy, Science Fiction
# Index: 180, Sum: tensor([[0.6105]]), Title: Ratatouille, Animation, Comedy, Family, Fantasy
# Index: 141, Sum: tensor([[0.6000]]), Title: Amelie, Comedy, Romance
# Index: 91, Sum: tensor([[0.5961]]), Title: Back to the Future, Adventure, Comedy, Science Fiction, Family
# Index: 147, Sum: tensor([[0.5853]]), Title: Spirited Away, Fantasy, Adventure, Animation, Family
# Index: 213, Sum: tensor([[0.5848]]), Title: Interstellar, Adventure, Drama, Science Fiction
# Index: 104, Sum: tensor([[0.5844]]), Title: On the Waterfront, Crime, Drama
# Index: 5, Sum: tensor([[0.5800]]), Title: The Usual Suspects, Drama, Crime, Thriller
# Index: 20, Sum: tensor([[0.5736]]), Title: Aladdin, Animation, Family, Comedy, Adventure, Fantasy, Romance
# Index: 143, Sum: tensor([[0.5734]]), Title: A Beautiful Mind, Drama, Romance
# Index: 6, Sum: tensor([[0.5698]]), Title: La Haine, Drama
# Index: 16, Sum: tensor([[0.5695]]), Title: In the Name of the Father, Drama
# Index: 209, Sum: tensor([[0.5693]]), Title: Rush, Drama, Action
# Index: 123, Sum: tensor([[0.5680]]), Title: Bicycle Thieves, Drama
# Index: 119, Sum: tensor([[0.5658]]), Title: The Sixth Sense, Mystery, Thriller, Drama
# Index: 128, Sum: tensor([[0.5644]]), Title: Double Indemnity, Drama, Mystery, Thriller
# Index: 100, Sum: tensor([[0.5625]]), Title: Good Will Hunting, Drama
# Index: 93, Sum: tensor([[0.5610]]), Title: The Great Dictator, Comedy
# Index: 129, Sum: tensor([[0.5586]]), Title: Modern Times, Drama, Comedy
# Index: 191, Sum: tensor([[0.5560]]), Title: The Secret in Their Eyes, Crime, Drama, Mystery, Romance
# Index: 146, Sum: tensor([[0.5559]]), Title: Rashomon, Crime, Drama, Mystery
# Index: 161, Sum: tensor([[0.5549]]), Title: Persona, Drama
# Index: 205, Sum: tensor([[0.5502]]), Title: The Intouchables, Drama, Comedy
# Index: 145, Sum: tensor([[0.5492]]), Title: Wild Strawberries, Drama
# Index: 62, Sum: tensor([[0.5486]]), Title: A Clockwork Orange, Science Fiction, Drama
# Index: 154, Sum: tensor([[0.5450]]), Title: Tokyo Story, Drama
# Index: 87, Sum: tensor([[0.5446]]), Title: The Great Escape, Adventure, Drama, History, Thriller, War
# Index: 54, Sum: tensor([[0.5444]]), Title: Paths of Glory, Drama, War
# Index: 55, Sum: tensor([[0.5441]]), Title: One Flew Over the Cuckoo's Nest, Drama
# Index: 160, Sum: tensor([[0.5402]]), Title: The Lord of the Rings: The Return of the King, Adventure, Fantasy, Action
# Index: 94, Sum: tensor([[0.5393]]), Title: Ben-Hur, Action, Adventure, Drama, History
# Index: 199, Sum: tensor([[0.5386]]), Title: Incendies, Drama, War, Mystery
# Index: 79, Sum: tensor([[0.5364]]), Title: The Terminator, Action, Thriller, Science Fiction
# Index: 26, Sum: tensor([[0.5322]]), Title: Trainspotting, Drama, Crime
# Index: 206, Sum: tensor([[0.5316]]), Title: The Hunt, Drama
# Index: 19, Sum: tensor([[0.5281]]), Title: Blade Runner, Science Fiction, Drama, Thriller
# Index: 151, Sum: tensor([[0.5280]]), Title: City of God, Drama, Crime
# Index: 196, Sum: tensor([[0.5218]]), Title: How to Train Your Dragon, Fantasy, Adventure, Animation, Family
# Index: 201, Sum: tensor([[0.5208]]), Title: The Help, Drama
# Index: 103, Sum: tensor([[0.5198]]), Title: The Best Years of Our Lives, Drama, History, Romance
# Index: 41, Sum: tensor([[0.5184]]), Title: All About Eve, Drama
# Index: 40, Sum: tensor([[0.5173]]), Title: 2001: A Space Odyssey, Science Fiction, Mystery, Adventure
# Index: 90, Sum: tensor([[0.5143]]), Title: Unforgiven, Western
# Index: 80, Sum: tensor([[0.5111]]), Title: Dead Poets Society, Drama
# Index: 88, Sum: tensor([[0.5089]]), Title: The Deer Hunter, Drama, War
# Index: 163, Sum: tensor([[0.5085]]), Title: The Wages of Fear, Drama, Thriller, Adventure
# Index: 179, Sum: tensor([[0.5055]]), Title: The Prestige, Drama, Mystery, Thriller
# Index: 173, Sum: tensor([[0.5049]]), Title: Downfall, Drama, History, War
# Index: 30, Sum: tensor([[0.5048]]), Title: Rear Window, Drama, Mystery, Thriller
# Index: 215, Sum: tensor([[0.5028]]), Title: Gone Girl, Mystery, Thriller, Drama
# Index: 53, Sum: tensor([[0.5007]]), Title: Cinema Paradiso, Drama, Romance
# Index: 182, Sum: tensor([[0.4994]]), Title: Into the Wild, Adventure, Drama
# Index: 157, Sum: tensor([[0.4991]]), Title: Come and See, Drama, History, War
# Index: 176, Sum: tensor([[0.4971]]), Title: The Lives of Others, Drama, Thriller
# Index: 177, Sum: tensor([[0.4957]]), Title: Pan's Labyrinth, Fantasy, Drama, War
# Index: 220, Sum: tensor([[0.4946]]), Title: Spotlight, Drama, Thriller, History
# Index: 22, Sum: tensor([[0.4941]]), Title: The Silence of the Lambs, Crime, Drama, Thriller
# Index: 135, Sum: tensor([[0.4888]]), Title: Requiem for a Dream, Crime, Drama
# Index: 165, Sum: tensor([[0.4880]]), Title: The Incredibles, Action, Adventure, Animation, Family
# Index: 170, Sum: tensor([[0.4880]]), Title: Million Dollar Baby, Drama
# Index: 7, Sum: tensor([[0.4833]]), Title: Braveheart, Action, Drama, History, War
# Index: 63, Sum: tensor([[0.4807]]), Title: To Kill a Mockingbird, Crime, Drama
# Index: 39, Sum: tensor([[0.4806]]), Title: Citizen Kane, Mystery, Drama
# Index: 133, Sum: tensor([[0.4802]]), Title: The Gold Rush, Adventure, Comedy, Drama
# Index: 136, Sum: tensor([[0.4789]]), Title: Snatch, Thriller, Crime
# Index: 23, Sum: tensor([[0.4751]]), Title: Fargo, Crime, Drama, Thriller
# Index: 74, Sum: tensor([[0.4732]]), Title: Once Upon a Time in America, Drama, Crime
# Index: 113, Sum: tensor([[0.4712]]), Title: American History X, Drama
# Index: 131, Sum: tensor([[0.4710]]), Title: Network, Drama
# Index: 12, Sum: tensor([[0.4675]]), Title: Pulp Fiction, Thriller, Crime
# Index: 10, Sum: tensor([[0.4664]]), Title: Star Wars, Adventure, Action, Science Fiction
# Index: 214, Sum: tensor([[0.4661]]), Title: Whiplash, Drama
# Index: 57, Sum: tensor([[0.4617]]), Title: Raiders of the Lost Ark, Adventure, Action
# Index: 85, Sum: tensor([[0.4596]]), Title: Stand by Me, Crime, Drama
# Index: 194, Sum: tensor([[0.4591]]), Title: 3 Idiots, Drama, Comedy, Romance
# Index: 211, Sum: tensor([[0.4564]]), Title: The Wolf of Wall Street, Crime, Drama, Comedy
# Index: 31, Sum: tensor([[0.4499]]), Title: It Happened One Night, Comedy, Romance
# Index: 9, Sum: tensor([[0.4491]]), Title: Before Sunrise, Drama, Romance
# Index: 187, Sum: tensor([[0.4490]]), Title: WALL夷똄, Animation, Family
# Index: 198, Sum: tensor([[0.4481]]), Title: Inception, Action, Thriller, Science Fiction, Mystery, Adventure
# Index: 11, Sum: tensor([[0.4479]]), Title: Leon: The Professional, Thriller, Crime, Drama
# Index: 29, Sum: tensor([[0.4470]]), Title: Vertigo, Mystery, Romance, Thriller
# Index: 77, Sum: tensor([[0.4467]]), Title: The Sting, Comedy, Crime, Drama
# Index: 178, Sum: tensor([[0.4463]]), Title: The Departed, Drama, Thriller, Crime
# Index: 164, Sum: tensor([[0.4438]]), Title: Before Sunset, Drama, Romance
# Index: 124, Sum: tensor([[0.4434]]), Title: The Grapes of Wrath, Drama
# Index: 71, Sum: tensor([[0.4430]]), Title: The Godfather: Part II, Drama, Crime
# Index: 38, Sum: tensor([[0.4422]]), Title: Sunset Boulevard, Drama
# Index: 162, Sum: tensor([[0.4409]]), Title: Eternal Sunshine of the Spotless Mind, Science Fiction, Drama, Romance
# Index: 105, Sum: tensor([[0.4408]]), Title: Rocky, Drama
# Index: 67, Sum: tensor([[0.4330]]), Title: The Third Man, Thriller, Mystery
# Index: 222, Sum: tensor([[0.4307]]), Title: Dangal, Drama
# Index: 158, Sum: tensor([[0.4209]]), Title: Kill Bill: Vol. 1, Action, Crime
# Index: 89, Sum: tensor([[0.4205]]), Title: Groundhog Day, Romance, Fantasy, Drama, Comedy
# Index: 210, Sum: tensor([[0.4205]]), Title: 12 Years a Slave, Drama, History
# Index: 189, Sum: tensor([[0.4201]]), Title: Inglourious Basterds, Drama, Action, Thriller, War
# Index: 96, Sum: tensor([[0.4191]]), Title: Gandhi, Drama, History
# Index: 207, Sum: tensor([[0.4163]]), Title: Django Unchained, Drama, Western
# Index: 59, Sum: tensor([[0.4158]]), Title: The Good, the Bad and the Ugly, Western
# Index: 92, Sum: tensor([[0.4152]]), Title: Cool Hand Luke, Crime, Drama
# Index: 159, Sum: tensor([[0.4127]]), Title: The Passion of Joan of Arc, Drama, History
# Index: 121, Sum: tensor([[0.4074]]), Title: Fight Club, Drama
# Index: 4, Sum: tensor([[0.3972]]), Title: Se7en, Crime, Mystery, Thriller
# Index: 152, Sum: tensor([[0.3894]]), Title: Finding Nemo, Animation, Family
# Index: 171, Sum: tensor([[0.3856]]), Title: Hotel Rwanda, Drama, History, War
# Index: 99, Sum: tensor([[0.3842]]), Title: The Truman Show, Comedy, Drama
# Index: 49, Sum: tensor([[0.3828]]), Title: Dial M for Murder, Crime, Mystery, Thriller
# Index: 144, Sum: tensor([[0.3813]]), Title: Witness for the Prosecution, Drama, Mystery, Crime
# Index: 17, Sum: tensor([[0.3803]]), Title: Jurassic Park, Adventure, Science Fiction
# Index: 208, Sum: tensor([[0.3779]]), Title: Prisoners, Drama, Thriller, Crime
# Index: 24, Sum: tensor([[0.3729]]), Title: Pather Panchali, Drama
# Index: 18, Sum: tensor([[0.3716]]), Title: Schindler's List, Drama, History, War
# Index: 195, Sum: tensor([[0.3697]]), Title: Shutter Island, Drama, Thriller, Mystery
# Index: 130, Sum: tensor([[0.3673]]), Title: Dersu Uzala, Action, Adventure, Drama
# Index: 106, Sum: tensor([[0.3666]]), Title: The Exorcist, Drama, Horror, Thriller
# Index: 216, Sum: tensor([[0.3651]]), Title: Wild Tales, Drama, Thriller, Comedy
# Index: 56, Sum: tensor([[0.3649]]), Title: The Empire Strikes Back, Adventure, Action, Science Fiction
# Index: 60, Sum: tensor([[0.3649]]), Title: 12 Angry Men, Drama
# Index: 188, Sum: tensor([[0.3609]]), Title: Gran Torino, Drama
# Index: 122, Sum: tensor([[0.3598]]), Title: The General, Action, Adventure, Comedy, Drama
# Index: 139, Sum: tensor([[0.3549]]), Title: Scarface, Action, Crime, Drama, Thriller
# Index: 86, Sum: tensor([[0.3549]]), Title: M, Drama, Action, Thriller, Crime
# Index: 221, Sum: tensor([[0.3510]]), Title: Hacksaw Ridge, Drama, History, War
# Index: 108, Sum: tensor([[0.3448]]), Title: Seven Samurai, Action, Drama
# Index: 166, Sum: tensor([[0.3444]]), Title: Sherlock, Jr., Fantasy, Drama, Comedy, Mystery
# Index: 167, Sum: tensor([[0.3436]]), Title: Harakiri, Action, Drama, History
# Index: 81, Sum: tensor([[0.3391]]), Title: The Bridge on the River Kwai, Drama, History, War
# Index: 97, Sum: tensor([[0.3385]]), Title: Jaws, Horror, Thriller, Adventure
# Index: 0, Sum: tensor([[0.3350]]), Title: merged_data
# Index: 193, Sum: tensor([[0.3331]]), Title: Hachi: A Dog's Tale, Drama, Family
# Index: 76, Sum: tensor([[0.3321]]), Title: Das Boot, Action, Drama, History, War, Adventure
# Index: 66, Sum: tensor([[0.3308]]), Title: Return of the Jedi, Adventure, Action, Science Fiction
# Index: 203, Sum: tensor([[0.3291]]), Title: Warrior, Action, Drama
# Index: 75, Sum: tensor([[0.3279]]), Title: Raging Bull, Drama
# Index: 98, Sum: tensor([[0.3254]]), Title: L.A. Confidential, Crime, Drama, Mystery, Thriller
# Index: 168, Sum: tensor([[0.3213]]), Title: The Battle of Algiers, Drama, War, History
# Index: 155, Sum: tensor([[0.3175]]), Title: Ikiru, Drama
# Index: 50, Sum: tensor([[0.3104]]), Title: Reservoir Dogs, Crime, Thriller
# Index: 95, Sum: tensor([[0.3086]]), Title: Indiana Jones and the Last Crusade, Adventure, Action
# Index: 110, Sum: tensor([[0.3062]]), Title: The Thing, Horror, Mystery, Science Fiction
# Index: 142, Sum: tensor([[0.3014]]), Title: The Lord of the Rings: The Fellowship of the Ring, Adventure, Fantasy, Action
# Index: 3, Sum: tensor([[0.2996]]), Title: Casino, Drama, Crime
# Index: 78, Sum: tensor([[0.2947]]), Title: The Seventh Seal, Fantasy, Drama
# Index: 156, Sum: tensor([[0.2916]]), Title: Judgment at Nuremberg, Drama, History
# Index: 148, Sum: tensor([[0.2834]]), Title: The Lord of the Rings: The Two Towers, Adventure, Fantasy, Action
# Index: 185, Sum: tensor([[0.2746]]), Title: Taare Zameen Par, Drama
# Index: 204, Sum: tensor([[0.2719]]), Title: The Dark Knight Rises, Action, Crime, Drama, Thriller
# Index: 117, Sum: tensor([[0.2618]]), Title: The 400 Blows, Drama
# Index: 82, Sum: tensor([[0.2546]]), Title: Chinatown, Crime, Drama, Mystery, Thriller
# Index: 58, Sum: tensor([[0.2519]]), Title: Aliens, Horror, Action, Thriller, Science Fiction
# Index: 109, Sum: tensor([[0.2418]]), Title: Saving Private Ryan, Drama, History, War
# Index: 2, Sum: tensor([[0.2407]]), Title: Heat, Action, Crime, Drama, Thriller
# Index: 114, Sum: tensor([[0.2095]]), Title: Lock, Stock and Two Smoking Barrels, Comedy, Crime
# Index: 115, Sum: tensor([[0.2056]]), Title: The Matrix, Action, Science Fiction
# Index: 69, Sum: tensor([[0.2020]]), Title: Alien, Horror, Action, Thriller, Science Fiction
# Index: 21, Sum: tensor([[0.1958]]), Title: Terminator 2: Judgment Day, Action, Thriller, Science Fiction
# Index: 174, Sum: tensor([[0.1946]]), Title: Batman Begins, Action, Crime, Drama
# Index: 134, Sum: tensor([[0.1721]]), Title: For a Few Dollars More, Western
# Index: 172, Sum: tensor([[0.1476]]), Title: Memories of Murder, Crime, Drama, Thriller
# Index: 107, Sum: tensor([[0.1199]]), Title: Metropolis, Drama, Science Fiction
# Index: 175, Sum: tensor([[0.0598]]), Title: V for Vendetta, Action, Thriller, Fantasy
